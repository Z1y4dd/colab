# %%
from dlisio import dlis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

pd.set_option('display.max_rows', 50)

# %% [markdown]
# # extracting lab

# %%
# loading lab_data from an Excel file
name = 'HRDH_697'
lab_data = pd.read_excel("../HRDH_LAB_DATA.xlsx", sheet_name=name, index_col='Depth_ft')

lab_data
# Out:
#           Sample_ID  XRD_Calcite  XRD_Dolomite  XRD_Ankerite  XRD_Siderite  \
# Depth_ft
# 14889.2           2            0             0             0             0
# 14893.8           3            0             0             0             0
# 14894.7           4            0             0             0             0
# 14895.3           5            0             0             0             0
# 14901.9           6            0             0             0             0
# 14903.7           7            0             0             0             0
# 14905.7           8            0             0             0             0
# 14931.5          14            0             0             0             0
# 14932.4          15            0             0             0             0
# 14938.5          17            0             0             0             0
#
#           XRD_Quartz  XRD_Plagioclase  XRD_K-Feldspar  XRD_Illite/Mica  \
# Depth_ft
# 14889.2         99.2                0             0.0              0.7
# 14893.8         96.1                0             0.0              3.8
# 14894.7         96.5                0             0.0              3.4
# 14895.3         95.1                0             0.0              4.8
# 14901.9         96.7                0             0.9              2.0
# 14903.7         97.4                0             0.0              2.5
# 14905.7         94.0                0             0.0              5.9
# 14931.5         92.0                0             0.0              7.9
# 14932.4         95.0                0             0.0              4.9
# 14938.5         95.0                0             0.0              4.9
#
#           XRD_Smectite  ...  XRF_S  XRF_Cl  XRF_K  XRF_Ca  XRF_Ti  XRF_Mn  \
# Depth_ft                ...
# 14889.2              0  ...   0.11    0.69   2.74    1.19    0.00       0
# 14893.8              0  ...   0.00    1.25   5.30    1.48    0.25       0
# 14894.7              0  ...   0.56    1.01   4.23    3.07    0.37       0
# 14895.3              0  ...   0.11    1.14   6.24    1.19    0.70       0
# 14901.9              0  ...   0.64    1.03   4.05    3.24    0.68       0
# 14903.7              0  ...   0.00    0.96   4.10    0.94    0.65       0
# 14905.7              0  ...   0.00    1.11   7.96    1.34    0.83       0
# 14931.5              0  ...   0.15    1.33   5.96    1.68    0.86       0
# 14932.4              0  ...   0.00    2.05   4.86    1.87    0.44       0
# 14938.5              0  ...   0.33    1.51   8.44    2.99    1.76       0
#
#           XRF_Fe  XRF_Zr  XRF_Sr  XRF_Ba
# Depth_ft
# 14889.2     0.59    0.14    0.00       0
# 14893.8     1.14    0.08    0.00       0
# 14894.7     0.98    0.08    0.00       0
# 14895.3     1.72    0.17    0.00       0
# 14901.9     1.68    0.22    0.00       0
# 14903.7     0.80    0.16    0.00       0
# 14905.7     1.63    0.00    0.04       0
# 14931.5     1.76    0.14    0.00       0
# 14932.4     1.48    0.10    0.00       0
# 14938.5     3.52    0.10    0.24       0
#
# [10 rows x 32 columns]

# %%
# convert data types to float
lab_data = lab_data.apply(pd.to_numeric, errors='coerce')


print("\n📋 DATAFRAME STRUCTURE:")
print(f"Index: {lab_data.index.name} (shape: {lab_data.index.shape})")
print(f"Columns: {list(lab_data.columns)} (shape: {lab_data.shape},)")
# print(f"Data types:\n{lab_data.info()}\n")


lab_data
# Out:
# 📋 DATAFRAME STRUCTURE:
# Index: Depth_ft (shape: (10,))
# Columns: ['Sample_ID', 'XRD_Calcite', 'XRD_Dolomite', 'XRD_Ankerite', 'XRD_Siderite', 'XRD_Quartz', 'XRD_Plagioclase', 'XRD_K-Feldspar', 'XRD_Illite/Mica', 'XRD_Smectite', 'XRD_Kaolinite', 'XRD_Chlorite', 'XRD_Mixed Clay', 'XRD_Anhydrite', 'XRD_Gypsum', 'XRD_Pyrite', 'XRD_Hematite', 'XRF_Na', 'XRF_Mg', 'XRF_Al', 'XRF_Si', 'XRF_P', 'XRF_S', 'XRF_Cl', 'XRF_K', 'XRF_Ca', 'XRF_Ti', 'XRF_Mn', 'XRF_Fe', 'XRF_Zr', 'XRF_Sr', 'XRF_Ba'] (shape: (10, 32),)
#           Sample_ID  XRD_Calcite  XRD_Dolomite  XRD_Ankerite  XRD_Siderite  \
# Depth_ft
# 14889.2           2            0             0             0             0
# 14893.8           3            0             0             0             0
# 14894.7           4            0             0             0             0
# 14895.3           5            0             0             0             0
# 14901.9           6            0             0             0             0
# 14903.7           7            0             0             0             0
# 14905.7           8            0             0             0             0
# 14931.5          14            0             0             0             0
# 14932.4          15            0             0             0             0
# 14938.5          17            0             0             0             0
#
#           XRD_Quartz  XRD_Plagioclase  XRD_K-Feldspar  XRD_Illite/Mica  \
# Depth_ft
# 14889.2         99.2                0             0.0              0.7
# 14893.8         96.1                0             0.0              3.8
# 14894.7         96.5                0             0.0              3.4
# 14895.3         95.1                0             0.0              4.8
# 14901.9         96.7                0             0.9              2.0
# 14903.7         97.4                0             0.0              2.5
# 14905.7         94.0                0             0.0              5.9
# 14931.5         92.0                0             0.0              7.9
# 14932.4         95.0                0             0.0              4.9
# 14938.5         95.0                0             0.0              4.9
#
#           XRD_Smectite  ...  XRF_S  XRF_Cl  XRF_K  XRF_Ca  XRF_Ti  XRF_Mn  \
# Depth_ft                ...
# 14889.2              0  ...   0.11    0.69   2.74    1.19    0.00       0
# 14893.8              0  ...   0.00    1.25   5.30    1.48    0.25       0
# 14894.7              0  ...   0.56    1.01   4.23    3.07    0.37       0
# 14895.3              0  ...   0.11    1.14   6.24    1.19    0.70       0
# 14901.9              0  ...   0.64    1.03   4.05    3.24    0.68       0
# 14903.7              0  ...   0.00    0.96   4.10    0.94    0.65       0
# 14905.7              0  ...   0.00    1.11   7.96    1.34    0.83       0
# 14931.5              0  ...   0.15    1.33   5.96    1.68    0.86       0
# 14932.4              0  ...   0.00    2.05   4.86    1.87    0.44       0
# 14938.5              0  ...   0.33    1.51   8.44    2.99    1.76       0
#
#           XRF_Fe  XRF_Zr  XRF_Sr  XRF_Ba
# Depth_ft
# 14889.2     0.59    0.14    0.00       0
# 14893.8     1.14    0.08    0.00       0
# 14894.7     0.98    0.08    0.00       0
# 14895.3     1.72    0.17    0.00       0
# 14901.9     1.68    0.22    0.00       0
# 14903.7     0.80    0.16    0.00       0
# 14905.7     1.63    0.00    0.04       0
# 14931.5     1.76    0.14    0.00       0
# 14932.4     1.48    0.10    0.00       0
# 14938.5     3.52    0.10    0.24       0
#
# [10 rows x 32 columns]

# %% [markdown]
# # extracting log dlis

# %%
from Module import load_full_dsl_log, dlis_to_df
import os
from pathlib import Path
import traceback
import glob
import pandas as pd

def load_full_dsl_log(

    root_dir: str,
    channels: list[str] | None = None,
    frame_idx: int = 0,
    priority_folders: list[str] | None = None
) -> tuple[pd.DataFrame, dict]:
    """
    Discover, filter, load, and concatenate DSL-based DLIS files into one continuous log.

    Args:
        root_dir: Root directory to search for .dlis files.
        channels: List of curve mnemonics to extract (None => all).
        frame_idx: Frame index to use for each DLIS.
        priority_folders: Ordered list of folder names to prefer when duplicates exist.

    Returns:
        full_log: DataFrame indexed by depth with concatenated log curves.
        metadata: Dictionary containing detailed loading information.
    """
    # 1. Discover all DLIS files
    found_files = glob.glob(f"{root_dir}/**/*.dlis", recursive=True)
    print(f"🔍 Found {len(found_files)} total DLIS files")

    # 2. Filter to DSL files only
    dsl_files = [f for f in found_files if "-DSL" in Path(f).stem]
    print(f"📊 Found {len(dsl_files)} DSL-specific files")

    if len(dsl_files) == 0:
        print("❌ No DSL files found!")
        return pd.DataFrame(), {"error": "No DSL files found"}

    # 3. Group by file stem to find duplicates
    stems = {}
    for f in dsl_files:
        stem = Path(f).stem
        stems.setdefault(stem, []).append(f)

    # 4. Select one file per stem based on priority_folders
    selected_files = []
    ignored_duplicates = []
    if priority_folders is None:
        priority_folders = ["Deliverables"]

    for stem, files in stems.items():
        if len(files) > 1:
            print(f"🔄 Multiple files found for {stem}: {len(files)} files")
            
        # pick highest-priority file
        selected = None
        for folder in priority_folders:
            for f in files:
                if folder in f:
                    selected = f
                    print(f"✅ Selected {Path(f).name} (priority: {folder})")
                    break
            if selected:
                break
        if not selected:
            selected = files[0]
            print(f"⚠️ No priority match for {stem}, using first file: {Path(selected).name}")
            
        selected_files.append(selected)
        # record ignored duplicates
        ignored_duplicates.extend([f for f in files if f != selected])

    print(f"📁 Selected {len(selected_files)} files for loading")
    print(f"🗑️ Ignored {len(ignored_duplicates)} duplicate files")

    # 5. Load each selected file into a DataFrame - FIXED PARAMETER NAMES
    dfs = []
    load_meta = []
    
    for i, f in enumerate(selected_files):
        try:
            print(f"\n🔧 Loading file {i+1}/{len(selected_files)}: {Path(f).name}")
            
            # FIXED: Use correct parameter names matching your Module's dlis_to_df function
            # Parameters: ['path', 'needed', 'frame_index', 'verbose']
            df = dlis_to_df(
                path=f, 
                needed=channels,        
                frame_index=frame_idx,  
                verbose=True            
            )
            
            # Handle the case where your function might return tuple or just DataFrame
            if isinstance(df, tuple):
                df, meta = df
                load_meta.append(meta)
            else:
                # If no metadata returned, create basic metadata
                meta = {
                    'path': f,
                    'shape': df.shape,
                    'columns': list(df.columns) if not df.empty else [],
                    'depth_range': (df.index.min(), df.index.max()) if not df.empty else (None, None)
                }
                load_meta.append(meta)
            
            if not df.empty:
                print(f"✅ Loaded: {df.shape[0]} samples × {df.shape[1]} channels")
                print(f"   Depth range: {df.index.min():.1f} - {df.index.max():.1f} ft")
                dfs.append(df)
            else:
                print(f"⚠️ Empty DataFrame returned for {Path(f).name}")
                
        except Exception as e:
            print(f"❌ Error loading {Path(f).name}: {e}")
            # Print more detailed error for debugging
            import traceback
            print(f"   Full error: {traceback.format_exc()}")
            continue

    # 6. Concatenate and deduplicate by depth index
    if dfs:
        print(f"\n🔗 Concatenating {len(dfs)} DataFrames...")
        
        # Concatenate with error handling
        try:
            full_log = pd.concat(dfs, sort=True).sort_index()
            
            # Check for depth duplicates
            duplicates_before = full_log.index.duplicated().sum()
            if duplicates_before > 0:
                print(f"⚠️ Found {duplicates_before} duplicate depths, removing...")
                full_log = full_log[~full_log.index.duplicated(keep='first')]
                
            print(f"✅ Final combined log: {full_log.shape[0]} samples × {full_log.shape[1]} channels")
            print(f"   Combined depth range: {full_log.index.min():.1f} - {full_log.index.max():.1f} ft")
            
        except Exception as e:
            print(f"❌ Error concatenating DataFrames: {e}")
            full_log = pd.DataFrame()
    else:
        print("❌ No valid DataFrames to concatenate")
        full_log = pd.DataFrame()

    # 7. Compile metadata
    metadata = {
        "found_files": found_files,
        "dsl_files": dsl_files,
        "selected_files": selected_files,
        "ignored_duplicates": ignored_duplicates,
        "load_meta": load_meta,
        "summary": {
            "total_files_found": len(found_files),
            "dsl_files_found": len(dsl_files),
            "files_loaded": len(dfs),
            "files_failed": len(selected_files) - len(dfs),
            "final_shape": full_log.shape if not full_log.empty else (0, 0)
        }
    }

    return full_log, metadata


# Path to the DLIS log file 
dir_path = r"\\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0"

log_df, meta = load_full_dsl_log(
    root_dir=dir_path,
    frame_idx=0,
    channels=None,
    priority_folders=["DELIVRABLES"]
    
)

# log_df, meta = load_full_log(root_dir=dir_path, file_type="dsl", priority_folders = ["DELIVRABLES"])


# Display summary
print(f"\n📊 LOADING SUMMARY:")
print(f"Files found: {meta['summary']['total_files_found']}")
# print(f"DSL files: {meta['summary']['dsl_files_found']}")
print(f"Successfully loaded: {meta['summary']['files_loaded']}")
print(f"Failed to load: {meta['summary']['files_failed']}")
print(f"Final shape: {meta['summary']['final_shape']}")

if not log_df.empty:
    print(f"Depth range: {log_df.index.min():.1f} - {log_df.index.max():.1f} ft")
    print(f"Available channels: {list(log_df.columns)}")
else:
    print("No data loaded - check errors above")

log_df
# Out:
# 🔍 Found 62 total DLIS files
# 📊 Found 7 DSL-specific files
# ⚠️ No priority match for HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_ML_BA, using first file: HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_ML_BA.dlis
# ⚠️ No priority match for HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_RP_BA, using first file: HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_RP_BA.dlis
# ⚠️ No priority match for HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_ML_BA, using first file: HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_ML_BA.dlis
# ⚠️ No priority match for HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_RPT_BA, using first file: HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_RPT_BA.dlis
# ⚠️ No priority match for HRDH_697_0_09JAN2012_ZDL-CN-DSL_ML_BA, using first file: HRDH_697_0_09JAN2012_ZDL-CN-DSL_ML_BA.dlis
# ⚠️ No priority match for HRDH_697_0_27OCT2011_ZDL-CN-DSL-GR_ML_BA, using first file: HRDH_697_0_27OCT2011_ZDL-CN-DSL-GR_ML_BA.dlis
# ⚠️ No priority match for HRDH_697_0_27OCT2011_ZDL-CNC-DSL-GR-CAL_ML_BA, using first file: HRDH_697_0_27OCT2011_ZDL-CNC-DSL-GR-CAL_ML_BA.dlis
# 📁 Selected 7 files for loading
# 🗑️ Ignored 0 duplicate files
#
# 🔧 Loading file 1/7: HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_ML_BA.dlis
# 🔍 STEP 1: FILE VALIDATION
# ========================================
# ✅ File found: HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_ML_BA.dlis
#    • Size: 24.5 MB
#    • Path: \\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\12\WL\Field\Deliverables\HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_ML_BA.dlis
#
# 🔍 STEP 2: DLIS FILE LOADING
# ========================================
# ✅ DLIS file loaded successfully
#    • Number of logical files: 1
#    • Using logical file: unnamed
#
# 🔍 STEP 3: FRAME VALIDATION
# ========================================
# ✅ Found 1 frame(s)
#    • Frame 0: 0.250000B0
# ✅ Selected frame 0: 0.250000B0
#
# 🔍 STEP 4: CHANNEL ANALYSIS
# ========================================
# ✅ Found 41 channels:
#     1. TDEP            | 0.250000 ft frame 0 depth      | Dim: [1] | Units: ft
#     2. BIT             | bit size                       | Dim: [1] | Units: in
#     3. CALZ1           | Dim: [1] | Units: in
#     4. CALZ2           | Dim: [1] | Units: in
#     5. CN              | compensated neutron porosity   | Dim: [1] | Units: pu
#     6. CNC             | borehole size corrected compensated neutron porosity | Dim: [1] | Units: pu
#     7. GR              | gamma ray                      | Dim: [1] | Units: gAPI
#     8. GRSL            | gamma ray from 1329 spectrum   | Dim: [1] | Units: gAPI
#     9. HRD1            | long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#    10. HRD12           | second tool long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#    11. K               | potassium content              | Dim: [1] | Units: %
#    12. KTH             | stripped potassium-thorium     | Dim: [1] | Units: gAPI
#    13. LSN             | long spaced neutron            | Dim: [1] | Units: 1/s
#    14. PE              | photo electric cross-section   | Dim: [1] | Units: b/e
#    15. PE2             | second tool photo electric cross-section | Dim: [1] | Units: b/e
#    16. QPKS            | number of peaks found          | Dim: [1] | Units:
#    17. RTHK            | ratio of thorium to potassium  | Dim: [1] | Units:
#    18. RTHU            | ratio of thorium to uranium    | Dim: [1] | Units:
#    19. RUK             | ratio of uranium to potassium  | Dim: [1] | Units:
#    20. SFT2            | long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    21. SFT22           | second tool long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    22. SHR             | soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    23. SHR2            | second tool soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    24. SLGN            | gain value                     | Dim: [1] | Units:
#    25. SLSP            | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units: 1/s
#    26. SLSP.0          | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units:
#    27. SLTM            | delta elapsed time             | Dim: [1] | Units: ms
#    28. SPD             | speed                          | Dim: [1] | Units: ft/min
#    29. SSD             | short spaced countrate         | Dim: [1] | Units:
#    30. SSD2            | second tool short spaced countrate | Dim: [1] | Units:
#    31. SSN             | short spaced countrate         | Dim: [1] | Units: 1/s
#    32. TEN             | differential tension           | Dim: [1] | Units: lbf
#    33. TH              | thorium concentration          | Dim: [1] | Units: ppm
#    34. TTEN            | total tension                  | Dim: [1] | Units: lbf
#    35. U               | uranium content                | Dim: [1] | Units: ppm
#    36. ZCOR            | density correction             | Dim: [1] | Units: g/cm3
#    37. ZCOR2           | second tool density correction | Dim: [1] | Units: g/cm3
#    38. ZDEN            | formation bulk density         | Dim: [1] | Units: g/cm3
#    39. ZDEN2           | second tool formation bulk density | Dim: [1] | Units: g/cm3
#    40. ZDNC            | borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
#    41. ZDNC2           | second tool borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
# ✅ Depth channel found: TDEP
#
# 🔍 STEP 5: DATA EXTRACTION
# ========================================
# ✅ Curves data extracted
#    • Data type: <class 'numpy.ndarray'>
#    • Shape: (14756,)
#    • Dtype: [('FRAMENO', '<i4'), (('T.CHANNEL-I.TDEP-O.0-C.0', 'TDEP'), '<f8'), (('T.CHANNEL-I.BIT-O.0-C.0', 'BIT'), '<f4'), (('T.CHANNEL-I.CALZ1-O.0-C.0', 'CALZ1'), '<f4'), (('T.CHANNEL-I.CALZ2-O.0-C.0', 'CALZ2'), '<f4'), (('T.CHANNEL-I.CN-O.0-C.0', 'CN'), '<f4'), (('T.CHANNEL-I.CNC-O.0-C.0', 'CNC'), '<f4'), (('T.CHANNEL-I.GR-O.0-C.0', 'GR'), '<f4'), (('T.CHANNEL-I.GRSL-O.0-C.0', 'GRSL'), '<f4'), (('T.CHANNEL-I.HRD1-O.0-C.0', 'HRD1'), '<f4'), (('T.CHANNEL-I.HRD12-O.0-C.0', 'HRD12'), '<f4'), (('T.CHANNEL-I.K-O.0-C.0', 'K'), '<f4'), (('T.CHANNEL-I.KTH-O.0-C.0', 'KTH'), '<f4'), (('T.CHANNEL-I.LSN-O.0-C.0', 'LSN'), '<f4'), (('T.CHANNEL-I.PE-O.0-C.0', 'PE'), '<f4'), (('T.CHANNEL-I.PE2-O.0-C.0', 'PE2'), '<f4'), (('T.CHANNEL-I.QPKS-O.0-C.0', 'QPKS'), '<i2'), (('T.CHANNEL-I.RTHK-O.0-C.0', 'RTHK'), '<f4'), (('T.CHANNEL-I.RTHU-O.0-C.0', 'RTHU'), '<f4'), (('T.CHANNEL-I.RUK-O.0-C.0', 'RUK'), '<f4'), (('T.CHANNEL-I.SFT2-O.0-C.0', 'SFT2'), '<f4'), (('T.CHANNEL-I.SFT22-O.0-C.0', 'SFT22'), '<f4'), (('T.CHANNEL-I.SHR-O.0-C.0', 'SHR'), '<f4'), (('T.CHANNEL-I.SHR2-O.0-C.0', 'SHR2'), '<f4'), (('T.CHANNEL-I.SLGN-O.0-C.0', 'SLGN'), '<f4'), (('T.CHANNEL-I.SLSP-O.0-C.0', 'SLSP'), '<f4', (254,)), (('T.CHANNEL-I.SLSP.0-O.0-C.0', 'SLSP.0'), '<u2', (254,)), (('T.CHANNEL-I.SLTM-O.0-C.0', 'SLTM'), '<f4'), (('T.CHANNEL-I.SPD-O.0-C.0', 'SPD'), '<f4'), (('T.CHANNEL-I.SSD-O.0-C.0', 'SSD'), '<f4'), (('T.CHANNEL-I.SSD2-O.0-C.0', 'SSD2'), '<f4'), (('T.CHANNEL-I.SSN-O.0-C.0', 'SSN'), '<f4'), (('T.CHANNEL-I.TEN-O.0-C.0', 'TEN'), '<f4'), (('T.CHANNEL-I.TH-O.0-C.0', 'TH'), '<f4'), (('T.CHANNEL-I.TTEN-O.0-C.0', 'TTEN'), '<f4'), (('T.CHANNEL-I.U-O.0-C.0', 'U'), '<f4'), (('T.CHANNEL-I.ZCOR-O.0-C.0', 'ZCOR'), '<f4'), (('T.CHANNEL-I.ZCOR2-O.0-C.0', 'ZCOR2'), '<f4'), (('T.CHANNEL-I.ZDEN-O.0-C.0', 'ZDEN'), '<f4'), (('T.CHANNEL-I.ZDEN2-O.0-C.0', 'ZDEN2'), '<f4'), (('T.CHANNEL-I.ZDNC-O.0-C.0', 'ZDNC'), '<f4'), (('T.CHANNEL-I.ZDNC2-O.0-C.0', 'ZDNC2'), '<f4')]
# ✅ Found 42 data fields
#
# 🔍 STEP 6: FIELD MAPPING
# ========================================
#    ✅ FRAMENO: 14756 samples
#    ✅ TDEP: 14756 samples
#    ✅ BIT: 14756 samples
#    ✅ CALZ1: 14756 samples
#    ✅ CALZ2: 14756 samples
#    ✅ CN: 14756 samples
#    ✅ CNC: 14756 samples
#    ✅ GR: 14756 samples
#    ✅ GRSL: 14756 samples
#    ✅ HRD1: 14756 samples
#    ✅ HRD12: 14756 samples
#    ✅ K: 14756 samples
#    ✅ KTH: 14756 samples
#    ✅ LSN: 14756 samples
#    ✅ PE: 14756 samples
#    ✅ PE2: 14756 samples
#    ✅ QPKS: 14756 samples
#    ✅ RTHK: 14756 samples
#    ✅ RTHU: 14756 samples
#    ✅ RUK: 14756 samples
#    ✅ SFT2: 14756 samples
#    ✅ SFT22: 14756 samples
#    ✅ SHR: 14756 samples
#    ✅ SHR2: 14756 samples
#    ✅ SLGN: 14756 samples
#    ⚠️ Skipping multi-dimensional: SLSP (14756, 254)
#    ⚠️ Skipping multi-dimensional: SLSP.0 (14756, 254)
#    ✅ SLTM: 14756 samples
#    ✅ SPD: 14756 samples
#    ✅ SSD: 14756 samples
#    ✅ SSD2: 14756 samples
#    ✅ SSN: 14756 samples
#    ✅ TEN: 14756 samples
#    ✅ TH: 14756 samples
#    ✅ TTEN: 14756 samples
#    ✅ U: 14756 samples
#    ✅ ZCOR: 14756 samples
#    ✅ ZCOR2: 14756 samples
#    ✅ ZDEN: 14756 samples
#    ✅ ZDEN2: 14756 samples
#    ✅ ZDNC: 14756 samples
#    ✅ ZDNC2: 14756 samples
#
# 📊 MAPPING SUMMARY:
#    • Successfully mapped: 40 fields
#    • Skipped: 2 fields
#    • Skipped list: ['SLSP (multi-dim)', 'SLSP.0 (multi-dim)']
#
# 🔍 STEP 7: DATAFRAME CREATION
# ========================================
# ✅ DataFrame created: (14756, 40)
# ✅ Set TDEP as index
#    • Depth range: 10855.00 - 14543.75
# ✅ Final DataFrame: (14756, 39)
# ✅ Loaded: 14756 samples × 39 channels
#    Depth range: 10855.0 - 14543.8 ft
#
# 🔧 Loading file 2/7: HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_RP_BA.dlis
# 🔍 STEP 1: FILE VALIDATION
# ========================================
# ✅ File found: HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_RP_BA.dlis
#    • Size: 3.2 MB
#    • Path: \\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\12\WL\Field\Deliverables\HRDH_697_0_15OCT2011_ZDL1-ZDL2-CN-DSL-GR_RP_BA.dlis
#
# 🔍 STEP 2: DLIS FILE LOADING
# ========================================
# ✅ DLIS file loaded successfully
#    • Number of logical files: 1
#    • Using logical file: unnamed
#
# 🔍 STEP 3: FRAME VALIDATION
# ========================================
# ✅ Found 1 frame(s)
#    • Frame 0: 0.250000B0
# ✅ Selected frame 0: 0.250000B0
#
# 🔍 STEP 4: CHANNEL ANALYSIS
# ========================================
# ✅ Found 41 channels:
#     1. TDEP            | 0.250000 ft frame 0 depth      | Dim: [1] | Units: ft
#     2. BIT             | bit size                       | Dim: [1] | Units: in
#     3. CALZ1           | Dim: [1] | Units: in
#     4. CALZ2           | Dim: [1] | Units: in
#     5. CN              | compensated neutron porosity   | Dim: [1] | Units: pu
#     6. CNC             | borehole size corrected compensated neutron porosity | Dim: [1] | Units: pu
#     7. GR              | gamma ray                      | Dim: [1] | Units: gAPI
#     8. GRSL            | gamma ray from 1329 spectrum   | Dim: [1] | Units: gAPI
#     9. HRD1            | long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#    10. HRD12           | second tool long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#    11. K               | potassium content              | Dim: [1] | Units: %
#    12. KTH             | stripped potassium-thorium     | Dim: [1] | Units: gAPI
#    13. LSN             | long spaced neutron            | Dim: [1] | Units: 1/s
#    14. PE              | photo electric cross-section   | Dim: [1] | Units: b/e
#    15. PE2             | second tool photo electric cross-section | Dim: [1] | Units: b/e
#    16. QPKS            | number of peaks found          | Dim: [1] | Units:
#    17. RTHK            | ratio of thorium to potassium  | Dim: [1] | Units:
#    18. RTHU            | ratio of thorium to uranium    | Dim: [1] | Units:
#    19. RUK             | ratio of uranium to potassium  | Dim: [1] | Units:
#    20. SFT2            | long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    21. SFT22           | second tool long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    22. SHR             | soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    23. SHR2            | second tool soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    24. SLGN            | gain value                     | Dim: [1] | Units:
#    25. SLSP            | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units: 1/s
#    26. SLSP.0          | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units:
#    27. SLTM            | delta elapsed time             | Dim: [1] | Units: ms
#    28. SPD             | speed                          | Dim: [1] | Units: ft/min
#    29. SSD             | short spaced countrate         | Dim: [1] | Units:
#    30. SSD2            | second tool short spaced countrate | Dim: [1] | Units:
#    31. SSN             | short spaced countrate         | Dim: [1] | Units: 1/s
#    32. TEN             | differential tension           | Dim: [1] | Units: lbf
#    33. TH              | thorium concentration          | Dim: [1] | Units: ppm
#    34. TTEN            | total tension                  | Dim: [1] | Units: lbf
#    35. U               | uranium content                | Dim: [1] | Units: ppm
#    36. ZCOR            | density correction             | Dim: [1] | Units: g/cm3
#    37. ZCOR2           | second tool density correction | Dim: [1] | Units: g/cm3
#    38. ZDEN            | formation bulk density         | Dim: [1] | Units: g/cm3
#    39. ZDEN2           | second tool formation bulk density | Dim: [1] | Units: g/cm3
#    40. ZDNC            | borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
#    41. ZDNC2           | second tool borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
# ✅ Depth channel found: TDEP
#
# 🔍 STEP 5: DATA EXTRACTION
# ========================================
# ✅ Curves data extracted
#    • Data type: <class 'numpy.ndarray'>
#    • Shape: (1669,)
#    • Dtype: [('FRAMENO', '<i4'), (('T.CHANNEL-I.TDEP-O.0-C.0', 'TDEP'), '<f8'), (('T.CHANNEL-I.BIT-O.0-C.0', 'BIT'), '<f4'), (('T.CHANNEL-I.CALZ1-O.0-C.0', 'CALZ1'), '<f4'), (('T.CHANNEL-I.CALZ2-O.0-C.0', 'CALZ2'), '<f4'), (('T.CHANNEL-I.CN-O.0-C.0', 'CN'), '<f4'), (('T.CHANNEL-I.CNC-O.0-C.0', 'CNC'), '<f4'), (('T.CHANNEL-I.GR-O.0-C.0', 'GR'), '<f4'), (('T.CHANNEL-I.GRSL-O.0-C.0', 'GRSL'), '<f4'), (('T.CHANNEL-I.HRD1-O.0-C.0', 'HRD1'), '<f4'), (('T.CHANNEL-I.HRD12-O.0-C.0', 'HRD12'), '<f4'), (('T.CHANNEL-I.K-O.0-C.0', 'K'), '<f4'), (('T.CHANNEL-I.KTH-O.0-C.0', 'KTH'), '<f4'), (('T.CHANNEL-I.LSN-O.0-C.0', 'LSN'), '<f4'), (('T.CHANNEL-I.PE-O.0-C.0', 'PE'), '<f4'), (('T.CHANNEL-I.PE2-O.0-C.0', 'PE2'), '<f4'), (('T.CHANNEL-I.QPKS-O.0-C.0', 'QPKS'), '<i2'), (('T.CHANNEL-I.RTHK-O.0-C.0', 'RTHK'), '<f4'), (('T.CHANNEL-I.RTHU-O.0-C.0', 'RTHU'), '<f4'), (('T.CHANNEL-I.RUK-O.0-C.0', 'RUK'), '<f4'), (('T.CHANNEL-I.SFT2-O.0-C.0', 'SFT2'), '<f4'), (('T.CHANNEL-I.SFT22-O.0-C.0', 'SFT22'), '<f4'), (('T.CHANNEL-I.SHR-O.0-C.0', 'SHR'), '<f4'), (('T.CHANNEL-I.SHR2-O.0-C.0', 'SHR2'), '<f4'), (('T.CHANNEL-I.SLGN-O.0-C.0', 'SLGN'), '<f4'), (('T.CHANNEL-I.SLSP-O.0-C.0', 'SLSP'), '<f4', (254,)), (('T.CHANNEL-I.SLSP.0-O.0-C.0', 'SLSP.0'), '<u2', (254,)), (('T.CHANNEL-I.SLTM-O.0-C.0', 'SLTM'), '<f4'), (('T.CHANNEL-I.SPD-O.0-C.0', 'SPD'), '<f4'), (('T.CHANNEL-I.SSD-O.0-C.0', 'SSD'), '<f4'), (('T.CHANNEL-I.SSD2-O.0-C.0', 'SSD2'), '<f4'), (('T.CHANNEL-I.SSN-O.0-C.0', 'SSN'), '<f4'), (('T.CHANNEL-I.TEN-O.0-C.0', 'TEN'), '<f4'), (('T.CHANNEL-I.TH-O.0-C.0', 'TH'), '<f4'), (('T.CHANNEL-I.TTEN-O.0-C.0', 'TTEN'), '<f4'), (('T.CHANNEL-I.U-O.0-C.0', 'U'), '<f4'), (('T.CHANNEL-I.ZCOR-O.0-C.0', 'ZCOR'), '<f4'), (('T.CHANNEL-I.ZCOR2-O.0-C.0', 'ZCOR2'), '<f4'), (('T.CHANNEL-I.ZDEN-O.0-C.0', 'ZDEN'), '<f4'), (('T.CHANNEL-I.ZDEN2-O.0-C.0', 'ZDEN2'), '<f4'), (('T.CHANNEL-I.ZDNC-O.0-C.0', 'ZDNC'), '<f4'), (('T.CHANNEL-I.ZDNC2-O.0-C.0', 'ZDNC2'), '<f4')]
# ✅ Found 42 data fields
#
# 🔍 STEP 6: FIELD MAPPING
# ========================================
#    ✅ FRAMENO: 1669 samples
#    ✅ TDEP: 1669 samples
#    ✅ BIT: 1669 samples
#    ✅ CALZ1: 1669 samples
#    ✅ CALZ2: 1669 samples
#    ✅ CN: 1669 samples
#    ✅ CNC: 1669 samples
#    ✅ GR: 1669 samples
#    ✅ GRSL: 1669 samples
#    ✅ HRD1: 1669 samples
#    ✅ HRD12: 1669 samples
#    ✅ K: 1669 samples
#    ✅ KTH: 1669 samples
#    ✅ LSN: 1669 samples
#    ✅ PE: 1669 samples
#    ✅ PE2: 1669 samples
#    ✅ QPKS: 1669 samples
#    ✅ RTHK: 1669 samples
#    ✅ RTHU: 1669 samples
#    ✅ RUK: 1669 samples
#    ✅ SFT2: 1669 samples
#    ✅ SFT22: 1669 samples
#    ✅ SHR: 1669 samples
#    ✅ SHR2: 1669 samples
#    ✅ SLGN: 1669 samples
#    ⚠️ Skipping multi-dimensional: SLSP (1669, 254)
#    ⚠️ Skipping multi-dimensional: SLSP.0 (1669, 254)
#    ✅ SLTM: 1669 samples
#    ✅ SPD: 1669 samples
#    ✅ SSD: 1669 samples
#    ✅ SSD2: 1669 samples
#    ✅ SSN: 1669 samples
#    ✅ TEN: 1669 samples
#    ✅ TH: 1669 samples
#    ✅ TTEN: 1669 samples
#    ✅ U: 1669 samples
#    ✅ ZCOR: 1669 samples
#    ✅ ZCOR2: 1669 samples
#    ✅ ZDEN: 1669 samples
#    ✅ ZDEN2: 1669 samples
#    ✅ ZDNC: 1669 samples
#    ✅ ZDNC2: 1669 samples
#
# 📊 MAPPING SUMMARY:
#    • Successfully mapped: 40 fields
#    • Skipped: 2 fields
#    • Skipped list: ['SLSP (multi-dim)', 'SLSP.0 (multi-dim)']
#
# 🔍 STEP 7: DATAFRAME CREATION
# ========================================
# ✅ DataFrame created: (1669, 40)
# ✅ Set TDEP as index
#    • Depth range: 11050.75 - 11467.75
# ✅ Final DataFrame: (1669, 39)
# ✅ Loaded: 1669 samples × 39 channels
#    Depth range: 11050.8 - 11467.8 ft
#
# 🔧 Loading file 3/7: HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_ML_BA.dlis
# 🔍 STEP 1: FILE VALIDATION
# ========================================
# ✅ File found: HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_ML_BA.dlis
#    • Size: 25.7 MB
#    • Path: \\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\12\WL\Field\FJA\HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_ML_BA.dlis
#
# 🔍 STEP 2: DLIS FILE LOADING
# ========================================
# ✅ DLIS file loaded successfully
#    • Number of logical files: 1
#    • Using logical file: unnamed
#
# 🔍 STEP 3: FRAME VALIDATION
# ========================================
# ✅ Found 1 frame(s)
#    • Frame 0: 0.250000B0
# ✅ Selected frame 0: 0.250000B0
#
# 🔍 STEP 4: CHANNEL ANALYSIS
# ========================================
# ✅ Found 39 channels:
#     1. TDEP            | 0.250000 ft frame 0 depth      | Dim: [1] | Units: ft
#     2. BIT             | bit size                       | Dim: [1] | Units: in
#     3. CN              | compensated neutron porosity   | Dim: [1] | Units: pu
#     4. CNC             | borehole size corrected compensated neutron porosity | Dim: [1] | Units: pu
#     5. GR              | gamma ray                      | Dim: [1] | Units: gAPI
#     6. GRSL            | gamma ray from 1329 spectrum   | Dim: [1] | Units: gAPI
#     7. HRD1            | long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#     8. HRD12           | second tool long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#     9. K               | potassium content              | Dim: [1] | Units: %
#    10. KTH             | stripped potassium-thorium     | Dim: [1] | Units: gAPI
#    11. LSN             | long spaced neutron            | Dim: [1] | Units: 1/s
#    12. PE              | photo electric cross-section   | Dim: [1] | Units: b/e
#    13. PE2             | second tool photo electric cross-section | Dim: [1] | Units: b/e
#    14. QPKS            | number of peaks found          | Dim: [1] | Units:
#    15. RTHK            | ratio of thorium to potassium  | Dim: [1] | Units:
#    16. RTHU            | ratio of thorium to uranium    | Dim: [1] | Units:
#    17. RUK             | ratio of uranium to potassium  | Dim: [1] | Units:
#    18. SFT2            | long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    19. SFT22           | second tool long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    20. SHR             | soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    21. SHR2            | second tool soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    22. SLGN            | gain value                     | Dim: [1] | Units:
#    23. SLSP            | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units: 1/s
#    24. SLSP.0          | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units:
#    25. SLTM            | delta elapsed time             | Dim: [1] | Units: ms
#    26. SPD             | speed                          | Dim: [1] | Units: ft/min
#    27. SSD             | short spaced countrate         | Dim: [1] | Units:
#    28. SSD2            | second tool short spaced countrate | Dim: [1] | Units:
#    29. SSN             | short spaced countrate         | Dim: [1] | Units: 1/s
#    30. TEN             | differential tension           | Dim: [1] | Units: lbf
#    31. TH              | thorium concentration          | Dim: [1] | Units: ppm
#    32. TTEN            | total tension                  | Dim: [1] | Units: lbf
#    33. U               | uranium content                | Dim: [1] | Units: ppm
#    34. ZCOR            | density correction             | Dim: [1] | Units: g/cm3
#    35. ZCOR2           | second tool density correction | Dim: [1] | Units: g/cm3
#    36. ZDEN            | formation bulk density         | Dim: [1] | Units: g/cm3
#    37. ZDEN2           | second tool formation bulk density | Dim: [1] | Units: g/cm3
#    38. ZDNC            | borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
#    39. ZDNC2           | second tool borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
# ✅ Depth channel found: TDEP
#
# 🔍 STEP 5: DATA EXTRACTION
# ========================================
# ✅ Curves data extracted
#    • Data type: <class 'numpy.ndarray'>
#    • Shape: (15603,)
#    • Dtype: [('FRAMENO', '<i4'), (('T.CHANNEL-I.TDEP-O.0-C.0', 'TDEP'), '<f8'), (('T.CHANNEL-I.BIT-O.0-C.0', 'BIT'), '<f4'), (('T.CHANNEL-I.CN-O.0-C.0', 'CN'), '<f4'), (('T.CHANNEL-I.CNC-O.0-C.0', 'CNC'), '<f4'), (('T.CHANNEL-I.GR-O.0-C.0', 'GR'), '<f4'), (('T.CHANNEL-I.GRSL-O.0-C.0', 'GRSL'), '<f4'), (('T.CHANNEL-I.HRD1-O.0-C.0', 'HRD1'), '<f4'), (('T.CHANNEL-I.HRD12-O.0-C.0', 'HRD12'), '<f4'), (('T.CHANNEL-I.K-O.0-C.0', 'K'), '<f4'), (('T.CHANNEL-I.KTH-O.0-C.0', 'KTH'), '<f4'), (('T.CHANNEL-I.LSN-O.0-C.0', 'LSN'), '<f4'), (('T.CHANNEL-I.PE-O.0-C.0', 'PE'), '<f4'), (('T.CHANNEL-I.PE2-O.0-C.0', 'PE2'), '<f4'), (('T.CHANNEL-I.QPKS-O.0-C.0', 'QPKS'), '<i2'), (('T.CHANNEL-I.RTHK-O.0-C.0', 'RTHK'), '<f4'), (('T.CHANNEL-I.RTHU-O.0-C.0', 'RTHU'), '<f4'), (('T.CHANNEL-I.RUK-O.0-C.0', 'RUK'), '<f4'), (('T.CHANNEL-I.SFT2-O.0-C.0', 'SFT2'), '<f4'), (('T.CHANNEL-I.SFT22-O.0-C.0', 'SFT22'), '<f4'), (('T.CHANNEL-I.SHR-O.0-C.0', 'SHR'), '<f4'), (('T.CHANNEL-I.SHR2-O.0-C.0', 'SHR2'), '<f4'), (('T.CHANNEL-I.SLGN-O.0-C.0', 'SLGN'), '<f4'), (('T.CHANNEL-I.SLSP-O.0-C.0', 'SLSP'), '<f4', (254,)), (('T.CHANNEL-I.SLSP.0-O.0-C.0', 'SLSP.0'), '<u2', (254,)), (('T.CHANNEL-I.SLTM-O.0-C.0', 'SLTM'), '<f4'), (('T.CHANNEL-I.SPD-O.0-C.0', 'SPD'), '<f4'), (('T.CHANNEL-I.SSD-O.0-C.0', 'SSD'), '<f4'), (('T.CHANNEL-I.SSD2-O.0-C.0', 'SSD2'), '<f4'), (('T.CHANNEL-I.SSN-O.0-C.0', 'SSN'), '<f4'), (('T.CHANNEL-I.TEN-O.0-C.0', 'TEN'), '<f4'), (('T.CHANNEL-I.TH-O.0-C.0', 'TH'), '<f4'), (('T.CHANNEL-I.TTEN-O.0-C.0', 'TTEN'), '<f4'), (('T.CHANNEL-I.U-O.0-C.0', 'U'), '<f4'), (('T.CHANNEL-I.ZCOR-O.0-C.0', 'ZCOR'), '<f4'), (('T.CHANNEL-I.ZCOR2-O.0-C.0', 'ZCOR2'), '<f4'), (('T.CHANNEL-I.ZDEN-O.0-C.0', 'ZDEN'), '<f4'), (('T.CHANNEL-I.ZDEN2-O.0-C.0', 'ZDEN2'), '<f4'), (('T.CHANNEL-I.ZDNC-O.0-C.0', 'ZDNC'), '<f4'), (('T.CHANNEL-I.ZDNC2-O.0-C.0', 'ZDNC2'), '<f4')]
# ✅ Found 40 data fields
#
# 🔍 STEP 6: FIELD MAPPING
# ========================================
#    ✅ FRAMENO: 15603 samples
#    ✅ TDEP: 15603 samples
#    ✅ BIT: 15603 samples
#    ✅ CN: 15603 samples
#    ✅ CNC: 15603 samples
#    ✅ GR: 15603 samples
#    ✅ GRSL: 15603 samples
#    ✅ HRD1: 15603 samples
#    ✅ HRD12: 15603 samples
#    ✅ K: 15603 samples
#    ✅ KTH: 15603 samples
#    ✅ LSN: 15603 samples
#    ✅ PE: 15603 samples
#    ✅ PE2: 15603 samples
#    ✅ QPKS: 15603 samples
#    ✅ RTHK: 15603 samples
#    ✅ RTHU: 15603 samples
#    ✅ RUK: 15603 samples
#    ✅ SFT2: 15603 samples
#    ✅ SFT22: 15603 samples
#    ✅ SHR: 15603 samples
#    ✅ SHR2: 15603 samples
#    ✅ SLGN: 15603 samples
#    ⚠️ Skipping multi-dimensional: SLSP (15603, 254)
#    ⚠️ Skipping multi-dimensional: SLSP.0 (15603, 254)
#    ✅ SLTM: 15603 samples
#    ✅ SPD: 15603 samples
#    ✅ SSD: 15603 samples
#    ✅ SSD2: 15603 samples
#    ✅ SSN: 15603 samples
#    ✅ TEN: 15603 samples
#    ✅ TH: 15603 samples
#    ✅ TTEN: 15603 samples
#    ✅ U: 15603 samples
#    ✅ ZCOR: 15603 samples
#    ✅ ZCOR2: 15603 samples
#    ✅ ZDEN: 15603 samples
#    ✅ ZDEN2: 15603 samples
#    ✅ ZDNC: 15603 samples
#    ✅ ZDNC2: 15603 samples
#
# 📊 MAPPING SUMMARY:
#    • Successfully mapped: 38 fields
#    • Skipped: 2 fields
#    • Skipped list: ['SLSP (multi-dim)', 'SLSP.0 (multi-dim)']
#
# 🔍 STEP 7: DATAFRAME CREATION
# ========================================
# ✅ DataFrame created: (15603, 38)
# ✅ Set TDEP as index
#    • Depth range: 10650.00 - 14550.50
# ✅ Final DataFrame: (15603, 37)
# ✅ Loaded: 15603 samples × 37 channels
#    Depth range: 10650.0 - 14550.5 ft
#
# 🔧 Loading file 4/7: HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_RPT_BA.dlis
# 🔍 STEP 1: FILE VALIDATION
# ========================================
# ✅ File found: HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_RPT_BA.dlis
#    • Size: 1.7 MB
#    • Path: \\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\12\WL\Field\FJA\HRDH_697_0_17OCT2011_ZDL-ZDL-CN-DSL_RPT_BA.dlis
#
# 🔍 STEP 2: DLIS FILE LOADING
# ========================================
# ✅ DLIS file loaded successfully
#    • Number of logical files: 1
#    • Using logical file: unnamed
#
# 🔍 STEP 3: FRAME VALIDATION
# ========================================
# ✅ Found 1 frame(s)
#    • Frame 0: 0.250000B0
# ✅ Selected frame 0: 0.250000B0
#
# 🔍 STEP 4: CHANNEL ANALYSIS
# ========================================
# ✅ Found 39 channels:
#     1. TDEP            | 0.250000 ft frame 0 depth      | Dim: [1] | Units: ft
#     2. BIT             | bit size                       | Dim: [1] | Units: in
#     3. CN              | compensated neutron porosity   | Dim: [1] | Units: pu
#     4. CNC             | borehole size corrected compensated neutron porosity | Dim: [1] | Units: pu
#     5. GR              | gamma ray                      | Dim: [1] | Units: gAPI
#     6. GRSL            | gamma ray from 1329 spectrum   | Dim: [1] | Units: gAPI
#     7. HRD1            | long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#     8. HRD12           | second tool long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#     9. K               | potassium content              | Dim: [1] | Units: %
#    10. KTH             | stripped potassium-thorium     | Dim: [1] | Units: gAPI
#    11. LSN             | long spaced neutron            | Dim: [1] | Units: 1/s
#    12. PE              | photo electric cross-section   | Dim: [1] | Units: b/e
#    13. PE2             | second tool photo electric cross-section | Dim: [1] | Units: b/e
#    14. QPKS            | number of peaks found          | Dim: [1] | Units:
#    15. RTHK            | ratio of thorium to potassium  | Dim: [1] | Units:
#    16. RTHU            | ratio of thorium to uranium    | Dim: [1] | Units:
#    17. RUK             | ratio of uranium to potassium  | Dim: [1] | Units:
#    18. SFT2            | long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    19. SFT22           | second tool long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    20. SHR             | soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    21. SHR2            | second tool soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    22. SLGN            | gain value                     | Dim: [1] | Units:
#    23. SLSP            | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units: 1/s
#    24. SLSP.0          | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units:
#    25. SLTM            | delta elapsed time             | Dim: [1] | Units: ms
#    26. SPD             | speed                          | Dim: [1] | Units: ft/min
#    27. SSD             | short spaced countrate         | Dim: [1] | Units:
#    28. SSD2            | second tool short spaced countrate | Dim: [1] | Units:
#    29. SSN             | short spaced countrate         | Dim: [1] | Units: 1/s
#    30. TEN             | differential tension           | Dim: [1] | Units: lbf
#    31. TH              | thorium concentration          | Dim: [1] | Units: ppm
#    32. TTEN            | total tension                  | Dim: [1] | Units: lbf
#    33. U               | uranium content                | Dim: [1] | Units: ppm
#    34. ZCOR            | density correction             | Dim: [1] | Units: g/cm3
#    35. ZCOR2           | second tool density correction | Dim: [1] | Units: g/cm3
#    36. ZDEN            | formation bulk density         | Dim: [1] | Units: g/cm3
#    37. ZDEN2           | second tool formation bulk density | Dim: [1] | Units: g/cm3
#    38. ZDNC            | borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
#    39. ZDNC2           | second tool borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
# ✅ Depth channel found: TDEP
#
# 🔍 STEP 5: DATA EXTRACTION
# ========================================
# ✅ Curves data extracted
#    • Data type: <class 'numpy.ndarray'>
#    • Shape: (801,)
#    • Dtype: [('FRAMENO', '<i4'), (('T.CHANNEL-I.TDEP-O.0-C.0', 'TDEP'), '<f8'), (('T.CHANNEL-I.BIT-O.0-C.0', 'BIT'), '<f4'), (('T.CHANNEL-I.CN-O.0-C.0', 'CN'), '<f4'), (('T.CHANNEL-I.CNC-O.0-C.0', 'CNC'), '<f4'), (('T.CHANNEL-I.GR-O.0-C.0', 'GR'), '<f4'), (('T.CHANNEL-I.GRSL-O.0-C.0', 'GRSL'), '<f4'), (('T.CHANNEL-I.HRD1-O.0-C.0', 'HRD1'), '<f4'), (('T.CHANNEL-I.HRD12-O.0-C.0', 'HRD12'), '<f4'), (('T.CHANNEL-I.K-O.0-C.0', 'K'), '<f4'), (('T.CHANNEL-I.KTH-O.0-C.0', 'KTH'), '<f4'), (('T.CHANNEL-I.LSN-O.0-C.0', 'LSN'), '<f4'), (('T.CHANNEL-I.PE-O.0-C.0', 'PE'), '<f4'), (('T.CHANNEL-I.PE2-O.0-C.0', 'PE2'), '<f4'), (('T.CHANNEL-I.QPKS-O.0-C.0', 'QPKS'), '<i2'), (('T.CHANNEL-I.RTHK-O.0-C.0', 'RTHK'), '<f4'), (('T.CHANNEL-I.RTHU-O.0-C.0', 'RTHU'), '<f4'), (('T.CHANNEL-I.RUK-O.0-C.0', 'RUK'), '<f4'), (('T.CHANNEL-I.SFT2-O.0-C.0', 'SFT2'), '<f4'), (('T.CHANNEL-I.SFT22-O.0-C.0', 'SFT22'), '<f4'), (('T.CHANNEL-I.SHR-O.0-C.0', 'SHR'), '<f4'), (('T.CHANNEL-I.SHR2-O.0-C.0', 'SHR2'), '<f4'), (('T.CHANNEL-I.SLGN-O.0-C.0', 'SLGN'), '<f4'), (('T.CHANNEL-I.SLSP-O.0-C.0', 'SLSP'), '<f4', (254,)), (('T.CHANNEL-I.SLSP.0-O.0-C.0', 'SLSP.0'), '<u2', (254,)), (('T.CHANNEL-I.SLTM-O.0-C.0', 'SLTM'), '<f4'), (('T.CHANNEL-I.SPD-O.0-C.0', 'SPD'), '<f4'), (('T.CHANNEL-I.SSD-O.0-C.0', 'SSD'), '<f4'), (('T.CHANNEL-I.SSD2-O.0-C.0', 'SSD2'), '<f4'), (('T.CHANNEL-I.SSN-O.0-C.0', 'SSN'), '<f4'), (('T.CHANNEL-I.TEN-O.0-C.0', 'TEN'), '<f4'), (('T.CHANNEL-I.TH-O.0-C.0', 'TH'), '<f4'), (('T.CHANNEL-I.TTEN-O.0-C.0', 'TTEN'), '<f4'), (('T.CHANNEL-I.U-O.0-C.0', 'U'), '<f4'), (('T.CHANNEL-I.ZCOR-O.0-C.0', 'ZCOR'), '<f4'), (('T.CHANNEL-I.ZCOR2-O.0-C.0', 'ZCOR2'), '<f4'), (('T.CHANNEL-I.ZDEN-O.0-C.0', 'ZDEN'), '<f4'), (('T.CHANNEL-I.ZDEN2-O.0-C.0', 'ZDEN2'), '<f4'), (('T.CHANNEL-I.ZDNC-O.0-C.0', 'ZDNC'), '<f4'), (('T.CHANNEL-I.ZDNC2-O.0-C.0', 'ZDNC2'), '<f4')]
# ✅ Found 40 data fields
#
# 🔍 STEP 6: FIELD MAPPING
# ========================================
#    ✅ FRAMENO: 801 samples
#    ✅ TDEP: 801 samples
#    ✅ BIT: 801 samples
#    ✅ CN: 801 samples
#    ✅ CNC: 801 samples
#    ✅ GR: 801 samples
#    ✅ GRSL: 801 samples
#    ✅ HRD1: 801 samples
#    ✅ HRD12: 801 samples
#    ✅ K: 801 samples
#    ✅ KTH: 801 samples
#    ✅ LSN: 801 samples
#    ✅ PE: 801 samples
#    ✅ PE2: 801 samples
#    ✅ QPKS: 801 samples
#    ✅ RTHK: 801 samples
#    ✅ RTHU: 801 samples
#    ✅ RUK: 801 samples
#    ✅ SFT2: 801 samples
#    ✅ SFT22: 801 samples
#    ✅ SHR: 801 samples
#    ✅ SHR2: 801 samples
#    ✅ SLGN: 801 samples
#    ⚠️ Skipping multi-dimensional: SLSP (801, 254)
#    ⚠️ Skipping multi-dimensional: SLSP.0 (801, 254)
#    ✅ SLTM: 801 samples
#    ✅ SPD: 801 samples
#    ✅ SSD: 801 samples
#    ✅ SSD2: 801 samples
#    ✅ SSN: 801 samples
#    ✅ TEN: 801 samples
#    ✅ TH: 801 samples
#    ✅ TTEN: 801 samples
#    ✅ U: 801 samples
#    ✅ ZCOR: 801 samples
#    ✅ ZCOR2: 801 samples
#    ✅ ZDEN: 801 samples
#    ✅ ZDEN2: 801 samples
#    ✅ ZDNC: 801 samples
#    ✅ ZDNC2: 801 samples
#
# 📊 MAPPING SUMMARY:
#    • Successfully mapped: 38 fields
#    • Skipped: 2 fields
#    • Skipped list: ['SLSP (multi-dim)', 'SLSP.0 (multi-dim)']
#
# 🔍 STEP 7: DATAFRAME CREATION
# ========================================
# ✅ DataFrame created: (801, 38)
# ✅ Set TDEP as index
#    • Depth range: 11200.00 - 11400.00
# ✅ Final DataFrame: (801, 37)
# ✅ Loaded: 801 samples × 37 channels
#    Depth range: 11200.0 - 11400.0 ft
#
# 🔧 Loading file 5/7: HRDH_697_0_09JAN2012_ZDL-CN-DSL_ML_BA.dlis
# 🔍 STEP 1: FILE VALIDATION
# ========================================
# ✅ File found: HRDH_697_0_09JAN2012_ZDL-CN-DSL_ML_BA.dlis
#    • Size: 11.9 MB
#    • Path: \\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\8375\WL\Field\Bottom_Section\Field\Deliverables\HRDH_697_0_09JAN2012_ZDL-CN-DSL_ML_BA.dlis
#
# 🔍 STEP 2: DLIS FILE LOADING
# ========================================
# ✅ DLIS file loaded successfully
#    • Number of logical files: 1
#    • Using logical file: unnamed
#
# 🔍 STEP 3: FRAME VALIDATION
# ========================================
# ✅ Found 3 frame(s)
#    • Frame 0: 0.500000B0
#    • Frame 1: 0.250000B1
#    • Frame 2: 0.250000B2
# ✅ Selected frame 0: 0.500000B0
#
# 🔍 STEP 4: CHANNEL ANALYSIS
# ========================================
# ✅ Found 30 channels:
#     1. TDEP            | 0.500000 ft frame 0 depth      | Dim: [1] | Units: ft
#     2. BIT             | bit size                       | Dim: [1] | Units: in
#     3. CHT.I           | cable head tension             | Dim: [1] | Units: lbf
#     4. CN              | compensated neutron porosity   | Dim: [1] | Units: pu
#     5. CNC             | borehole size corrected compensated neutron porosity | Dim: [1] | Units: pu
#     6. GR              | gamma ray                      | Dim: [1] | Units: gAPI
#     7. GRSL            | gamma ray from 1329 spectrum   | Dim: [1] | Units: gAPI
#     8. HRD1            | long space spectrum countrate 140 - 200 KeV | Dim: [1] | Units:
#     9. HRD2            | long space spectrum countrate 200 - 540 KeV | Dim: [1] | Units:
#    10. K               | potassium content              | Dim: [1] | Units: %
#    11. KTH             | stripped potassium-thorium     | Dim: [1] | Units: gAPI
#    12. LSN             | long spaced neutron            | Dim: [1] | Units: 1/s
#    13. PE              | photo electric cross-section   | Dim: [1] | Units: b/e
#    14. QPKS            | number of peaks found          | Dim: [1] | Units:
#    15. RTHK            | ratio of thorium to potassium  | Dim: [1] | Units:
#    16. RTHU            | ratio of thorium to uranium    | Dim: [1] | Units:
#    17. RUK             | ratio of uranium to potassium  | Dim: [1] | Units:
#    18. SFT2            | long spaced spectrum countrate 100 - 140 KeV | Dim: [1] | Units:
#    19. SHR             | soft to hard countrate ratio (soft/hrd2) | Dim: [1] | Units:
#    20. SLGN            | gain value                     | Dim: [1] | Units:
#    21. SLSP            | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units: 1/s
#    22. SLTM            | delta elapsed time             | Dim: [1] | Units: ms
#    23. SSD             | short spaced countrate         | Dim: [1] | Units:
#    24. SSN             | short spaced countrate         | Dim: [1] | Units: 1/s
#    25. TH              | thorium concentration          | Dim: [1] | Units: ppm
#    26. U               | uranium content                | Dim: [1] | Units: ppm
#    27. WTBH            | temperature of the borehole    | Dim: [1] | Units: degF
#    28. ZCOR            | density correction             | Dim: [1] | Units: g/cm3
#    29. ZDEN            | formation bulk density         | Dim: [1] | Units: g/cm3
#    30. ZDNC            | borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
# ✅ Depth channel found: TDEP
#
# 🔍 STEP 5: DATA EXTRACTION
# ========================================
# ✅ Curves data extracted
#    • Data type: <class 'numpy.ndarray'>
#    • Shape: (9643,)
#    • Dtype: [('FRAMENO', '<i4'), (('T.CHANNEL-I.TDEP-O.0-C.0', 'TDEP'), '<f8'), (('T.CHANNEL-I.BIT-O.0-C.0', 'BIT'), '<f4'), (('T.CHANNEL-I.CHT.I-O.0-C.0', 'CHT.I'), '<f4'), (('T.CHANNEL-I.CN-O.0-C.0', 'CN'), '<f4'), (('T.CHANNEL-I.CNC-O.0-C.0', 'CNC'), '<f4'), (('T.CHANNEL-I.GR-O.0-C.0', 'GR'), '<f4'), (('T.CHANNEL-I.GRSL-O.0-C.0', 'GRSL'), '<f4'), (('T.CHANNEL-I.HRD1-O.0-C.0', 'HRD1'), '<f4'), (('T.CHANNEL-I.HRD2-O.0-C.0', 'HRD2'), '<f4'), (('T.CHANNEL-I.K-O.0-C.0', 'K'), '<f4'), (('T.CHANNEL-I.KTH-O.0-C.0', 'KTH'), '<f4'), (('T.CHANNEL-I.LSN-O.0-C.0', 'LSN'), '<f4'), (('T.CHANNEL-I.PE-O.0-C.0', 'PE'), '<f4'), (('T.CHANNEL-I.QPKS-O.0-C.0', 'QPKS'), '<i2'), (('T.CHANNEL-I.RTHK-O.0-C.0', 'RTHK'), '<f4'), (('T.CHANNEL-I.RTHU-O.0-C.0', 'RTHU'), '<f4'), (('T.CHANNEL-I.RUK-O.0-C.0', 'RUK'), '<f4'), (('T.CHANNEL-I.SFT2-O.0-C.0', 'SFT2'), '<f4'), (('T.CHANNEL-I.SHR-O.0-C.0', 'SHR'), '<f4'), (('T.CHANNEL-I.SLGN-O.0-C.0', 'SLGN'), '<f4'), (('T.CHANNEL-I.SLSP-O.0-C.0', 'SLSP'), '<f4', (254,)), (('T.CHANNEL-I.SLTM-O.0-C.0', 'SLTM'), '<f4'), (('T.CHANNEL-I.SSD-O.0-C.0', 'SSD'), '<f4'), (('T.CHANNEL-I.SSN-O.0-C.0', 'SSN'), '<f4'), (('T.CHANNEL-I.TH-O.0-C.0', 'TH'), '<f4'), (('T.CHANNEL-I.U-O.0-C.0', 'U'), '<f4'), (('T.CHANNEL-I.WTBH-O.0-C.0', 'WTBH'), '<f4'), (('T.CHANNEL-I.ZCOR-O.0-C.0', 'ZCOR'), '<f4'), (('T.CHANNEL-I.ZDEN-O.0-C.0', 'ZDEN'), '<f4'), (('T.CHANNEL-I.ZDNC-O.0-C.0', 'ZDNC'), '<f4')]
# ✅ Found 31 data fields
#
# 🔍 STEP 6: FIELD MAPPING
# ========================================
#    ✅ FRAMENO: 9643 samples
#    ✅ TDEP: 9643 samples
#    ✅ BIT: 9643 samples
#    ✅ CHT.I: 9643 samples
#    ✅ CN: 9643 samples
#    ✅ CNC: 9643 samples
#    ✅ GR: 9643 samples
#    ✅ GRSL: 9643 samples
#    ✅ HRD1: 9643 samples
#    ✅ HRD2: 9643 samples
#    ✅ K: 9643 samples
#    ✅ KTH: 9643 samples
#    ✅ LSN: 9643 samples
#    ✅ PE: 9643 samples
#    ✅ QPKS: 9643 samples
#    ✅ RTHK: 9643 samples
#    ✅ RTHU: 9643 samples
#    ✅ RUK: 9643 samples
#    ✅ SFT2: 9643 samples
#    ✅ SHR: 9643 samples
#    ✅ SLGN: 9643 samples
#    ⚠️ Skipping multi-dimensional: SLSP (9643, 254)
#    ✅ SLTM: 9643 samples
#    ✅ SSD: 9643 samples
#    ✅ SSN: 9643 samples
#    ✅ TH: 9643 samples
#    ✅ U: 9643 samples
#    ✅ WTBH: 9643 samples
#    ✅ ZCOR: 9643 samples
#    ✅ ZDEN: 9643 samples
#    ✅ ZDNC: 9643 samples
#
# 📊 MAPPING SUMMARY:
#    • Successfully mapped: 30 fields
#    • Skipped: 1 fields
#    • Skipped list: ['SLSP (multi-dim)']
#
# 🔍 STEP 7: DATAFRAME CREATION
# ========================================
# ✅ DataFrame created: (9643, 30)
# ✅ Set TDEP as index
#    • Depth range: 14315.00 - 19136.00
# ✅ Final DataFrame: (9643, 29)
# ✅ Loaded: 9643 samples × 29 channels
#    Depth range: 14315.0 - 19136.0 ft
#
# 🔧 Loading file 6/7: HRDH_697_0_27OCT2011_ZDL-CN-DSL-GR_ML_BA.dlis
# 🔍 STEP 1: FILE VALIDATION
# ========================================
# ✅ File found: HRDH_697_0_27OCT2011_ZDL-CN-DSL-GR_ML_BA.dlis
#    • Size: 1.7 MB
#    • Path: \\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\8375\WL\Field\Top_Section\Field\Deliverables\HRDH_697_0_27OCT2011_ZDL-CN-DSL-GR_ML_BA.dlis
#
# 🔍 STEP 2: DLIS FILE LOADING
# ========================================
# ✅ DLIS file loaded successfully
#    • Number of logical files: 1
#    • Using logical file: unnamed
#
# 🔍 STEP 3: FRAME VALIDATION
# ========================================
# ✅ Found 1 frame(s)
#    • Frame 0: 0_250000B0
# ✅ Selected frame 0: 0_250000B0
#
# 🔍 STEP 4: CHANNEL ANALYSIS
# ========================================
# ✅ Found 35 channels:
#     1. TDEP            | 0.250000 ft frame 0 depth      | Dim: [1] | Units: ft
#     2. BIT             | Bit size                       | Dim: [1] | Units: in
#     3. BVOL            | Borehole volume                | Dim: [1] | Units: ft3
#     4. CALZ            | Dim: [1] | Units: in
#     5. CN              | Compensated neutron porosity   | Dim: [1] | Units: pu
#     6. CNC             | Borehole size corrected compensated neutron porosity | Dim: [1] | Units: pu
#     7. CVOL            | Cement volume                  | Dim: [1] | Units: ft3
#     8. GR              | Gamma ray                      | Dim: [1] | Units: gAPI
#     9. GRSL            | Gamma ray from 1329 spectrum   | Dim: [1] | Units: gAPI
#    10. HRD1            | Long space spectrum count rate 140-200 keV | Dim: [1] | Units:
#    11. HRD2            | Long space spectrum count rate 200-540 keV | Dim: [1] | Units:
#    12. K               | Potassium content              | Dim: [1] | Units: %
#    13. KTH             | Stripped potassium-thorium     | Dim: [1] | Units: gAPI
#    14. LSN             | Long space neutron             | Dim: [1] | Units: 1/s
#    15. PE              | Photo electric cross-section   | Dim: [1] | Units: b/e
#    16. QPKS            | Number of peaks found          | Dim: [1] | Units:
#    17. RTHK            | Ratio of thorium to potassium  | Dim: [1] | Units:
#    18. RTHU            | Ratio of thorium to uranium    | Dim: [1] | Units:
#    19. RUK             | Ratio of uranium to potassium  | Dim: [1] | Units:
#    20. SFT2            | Long space spectrum count rate 100-140 keV | Dim: [1] | Units:
#    21. SHR             | Soft to hard count rate ratio (SOFT/HRD2) | Dim: [1] | Units:
#    22. SLGN            | Gain value                     | Dim: [1] | Units:
#    23. SLSP            | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units: 1/s
#    24. SLSPQ0          | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units:
#    25. SLTM            | Delta elapsed time             | Dim: [1] | Units: ms
#    26. SPD             | Speed                          | Dim: [1] | Units: ft/min
#    27. SSD             | Short space count rate         | Dim: [1] | Units:
#    28. SSN             | Short space count rate         | Dim: [1] | Units: 1/s
#    29. TEN             | Differential tension           | Dim: [1] | Units: lbf
#    30. TH              | Thorium concentration          | Dim: [1] | Units: ppm
#    31. TTEN            | Total tension                  | Dim: [1] | Units: lbf
#    32. U               | Uranium content                | Dim: [1] | Units: ppm
#    33. ZCOR            | Density correction             | Dim: [1] | Units: g/cm3
#    34. ZDEN            | Formation bulk density         | Dim: [1] | Units: g/cm3
#    35. ZDNC            | Borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
# ✅ Depth channel found: TDEP
#
# 🔍 STEP 5: DATA EXTRACTION
# ========================================
# ✅ Curves data extracted
#    • Data type: <class 'numpy.ndarray'>
#    • Shape: (947,)
#    • Dtype: [('FRAMENO', '<i4'), (('T.CHANNEL-I.TDEP-O.1-C.0', 'TDEP'), '<f8'), (('T.CHANNEL-I.BIT-O.1-C.0', 'BIT'), '<f4'), (('T.CHANNEL-I.BVOL-O.1-C.0', 'BVOL'), '<f4'), (('T.CHANNEL-I.CALZ-O.1-C.0', 'CALZ'), '<f4'), (('T.CHANNEL-I.CN-O.1-C.0', 'CN'), '<f4'), (('T.CHANNEL-I.CNC-O.1-C.0', 'CNC'), '<f4'), (('T.CHANNEL-I.CVOL-O.1-C.0', 'CVOL'), '<f4'), (('T.CHANNEL-I.GR-O.1-C.0', 'GR'), '<f4'), (('T.CHANNEL-I.GRSL-O.1-C.0', 'GRSL'), '<f4'), (('T.CHANNEL-I.HRD1-O.1-C.0', 'HRD1'), '<f4'), (('T.CHANNEL-I.HRD2-O.1-C.0', 'HRD2'), '<f4'), (('T.CHANNEL-I.K-O.1-C.0', 'K'), '<f4'), (('T.CHANNEL-I.KTH-O.1-C.0', 'KTH'), '<f4'), (('T.CHANNEL-I.LSN-O.1-C.0', 'LSN'), '<f4'), (('T.CHANNEL-I.PE-O.1-C.0', 'PE'), '<f4'), (('T.CHANNEL-I.QPKS-O.1-C.0', 'QPKS'), '<i2'), (('T.CHANNEL-I.RTHK-O.1-C.0', 'RTHK'), '<f4'), (('T.CHANNEL-I.RTHU-O.1-C.0', 'RTHU'), '<f4'), (('T.CHANNEL-I.RUK-O.1-C.0', 'RUK'), '<f4'), (('T.CHANNEL-I.SFT2-O.1-C.0', 'SFT2'), '<f4'), (('T.CHANNEL-I.SHR-O.1-C.0', 'SHR'), '<f4'), (('T.CHANNEL-I.SLGN-O.1-C.0', 'SLGN'), '<f4'), (('T.CHANNEL-I.SLSP-O.1-C.0', 'SLSP'), '<f4', (254,)), (('T.CHANNEL-I.SLSPQ0-O.1-C.0', 'SLSPQ0'), '<u2', (254,)), (('T.CHANNEL-I.SLTM-O.1-C.0', 'SLTM'), '<f4'), (('T.CHANNEL-I.SPD-O.1-C.0', 'SPD'), '<f4'), (('T.CHANNEL-I.SSD-O.1-C.0', 'SSD'), '<f4'), (('T.CHANNEL-I.SSN-O.1-C.0', 'SSN'), '<f4'), (('T.CHANNEL-I.TEN-O.1-C.0', 'TEN'), '<f4'), (('T.CHANNEL-I.TH-O.1-C.0', 'TH'), '<f4'), (('T.CHANNEL-I.TTEN-O.1-C.0', 'TTEN'), '<f4'), (('T.CHANNEL-I.U-O.1-C.0', 'U'), '<f4'), (('T.CHANNEL-I.ZCOR-O.1-C.0', 'ZCOR'), '<f4'), (('T.CHANNEL-I.ZDEN-O.1-C.0', 'ZDEN'), '<f4'), (('T.CHANNEL-I.ZDNC-O.1-C.0', 'ZDNC'), '<f4')]
# ✅ Found 36 data fields
#
# 🔍 STEP 6: FIELD MAPPING
# ========================================
#    ✅ FRAMENO: 947 samples
#    ✅ TDEP: 947 samples
#    ✅ BIT: 947 samples
#    ✅ BVOL: 947 samples
#    ✅ CALZ: 947 samples
#    ✅ CN: 947 samples
#    ✅ CNC: 947 samples
#    ✅ CVOL: 947 samples
#    ✅ GR: 947 samples
#    ✅ GRSL: 947 samples
#    ✅ HRD1: 947 samples
#    ✅ HRD2: 947 samples
#    ✅ K: 947 samples
#    ✅ KTH: 947 samples
#    ✅ LSN: 947 samples
#    ✅ PE: 947 samples
#    ✅ QPKS: 947 samples
#    ✅ RTHK: 947 samples
#    ✅ RTHU: 947 samples
#    ✅ RUK: 947 samples
#    ✅ SFT2: 947 samples
#    ✅ SHR: 947 samples
#    ✅ SLGN: 947 samples
#    ⚠️ Skipping multi-dimensional: SLSP (947, 254)
#    ⚠️ Skipping multi-dimensional: SLSPQ0 (947, 254)
#    ✅ SLTM: 947 samples
#    ✅ SPD: 947 samples
#    ✅ SSD: 947 samples
#    ✅ SSN: 947 samples
#    ✅ TEN: 947 samples
#    ✅ TH: 947 samples
#    ✅ TTEN: 947 samples
#    ✅ U: 947 samples
#    ✅ ZCOR: 947 samples
#    ✅ ZDEN: 947 samples
#    ✅ ZDNC: 947 samples
#
# 📊 MAPPING SUMMARY:
#    • Successfully mapped: 34 fields
#    • Skipped: 2 fields
#    • Skipped list: ['SLSP (multi-dim)', 'SLSPQ0 (multi-dim)']
#
# 🔍 STEP 7: DATAFRAME CREATION
# ========================================
# ✅ DataFrame created: (947, 34)
# ✅ Set TDEP as index
#    • Depth range: 14516.00 - 14752.50
# ✅ Final DataFrame: (947, 33)
# ✅ Loaded: 947 samples × 33 channels
#    Depth range: 14516.0 - 14752.5 ft
#
# 🔧 Loading file 7/7: HRDH_697_0_27OCT2011_ZDL-CNC-DSL-GR-CAL_ML_BA.dlis
# 🔍 STEP 1: FILE VALIDATION
# ========================================
# ✅ File found: HRDH_697_0_27OCT2011_ZDL-CNC-DSL-GR-CAL_ML_BA.dlis
#    • Size: 1.7 MB
#    • Path: \\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\8375\WL\Field\Top_Section\Field\FJA\GSLAM\HRDH_697_0_27OCT2011_ZDL-CNC-DSL-GR-CAL_ML_BA.dlis
#
# 🔍 STEP 2: DLIS FILE LOADING
# ========================================
# ✅ DLIS file loaded successfully
#    • Number of logical files: 1
#    • Using logical file: unnamed
#
# 🔍 STEP 3: FRAME VALIDATION
# ========================================
# ✅ Found 1 frame(s)
#    • Frame 0: 0_250000B0
# ✅ Selected frame 0: 0_250000B0
#
# 🔍 STEP 4: CHANNEL ANALYSIS
# ========================================
# ✅ Found 35 channels:
#     1. TDEP            | 0.250000 ft frame 0 depth      | Dim: [1] | Units: ft
#     2. BIT             | Bit size                       | Dim: [1] | Units: in
#     3. BVOL            | Borehole volume                | Dim: [1] | Units: ft3
#     4. CALZ            | Dim: [1] | Units: in
#     5. CN              | Compensated neutron porosity   | Dim: [1] | Units: pu
#     6. CNC             | Borehole size corrected compensated neutron porosity | Dim: [1] | Units: pu
#     7. CVOL            | Cement volume                  | Dim: [1] | Units: ft3
#     8. GR              | Gamma ray                      | Dim: [1] | Units: gAPI
#     9. GRSL            | Gamma ray from 1329 spectrum   | Dim: [1] | Units: gAPI
#    10. HRD1            | Long space spectrum count rate 140-200 keV | Dim: [1] | Units:
#    11. HRD2            | Long space spectrum count rate 200-540 keV | Dim: [1] | Units:
#    12. K               | Potassium content              | Dim: [1] | Units: %
#    13. KTH             | Stripped potassium-thorium     | Dim: [1] | Units: gAPI
#    14. LSN             | Long space neutron             | Dim: [1] | Units: 1/s
#    15. PE              | Photo electric cross-section   | Dim: [1] | Units: b/e
#    16. QPKS            | Number of peaks found          | Dim: [1] | Units:
#    17. RTHK            | Ratio of thorium to potassium  | Dim: [1] | Units:
#    18. RTHU            | Ratio of thorium to uranium    | Dim: [1] | Units:
#    19. RUK             | Ratio of uranium to potassium  | Dim: [1] | Units:
#    20. SFT2            | Long space spectrum count rate 100-140 keV | Dim: [1] | Units:
#    21. SHR             | Soft to hard count rate ratio (SOFT/HRD2) | Dim: [1] | Units:
#    22. SLGN            | Gain value                     | Dim: [1] | Units:
#    23. SLSP            | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units: 1/s
#    24. SLSPQ0          | SL spectrum channels 1-254 (subset 0) | Dim: [254] | Units:
#    25. SLTM            | Delta elapsed time             | Dim: [1] | Units: ms
#    26. SPD             | Speed                          | Dim: [1] | Units: ft/min
#    27. SSD             | Short space count rate         | Dim: [1] | Units:
#    28. SSN             | Short space count rate         | Dim: [1] | Units: 1/s
#    29. TEN             | Differential tension           | Dim: [1] | Units: lbf
#    30. TH              | Thorium concentration          | Dim: [1] | Units: ppm
#    31. TTEN            | Total tension                  | Dim: [1] | Units: lbf
#    32. U               | Uranium content                | Dim: [1] | Units: ppm
#    33. ZCOR            | Density correction             | Dim: [1] | Units: g/cm3
#    34. ZDEN            | Formation bulk density         | Dim: [1] | Units: g/cm3
#    35. ZDNC            | Borehole size/mud weight corrected density | Dim: [1] | Units: g/cm3
# ✅ Depth channel found: TDEP
#
# 🔍 STEP 5: DATA EXTRACTION
# ========================================
# ✅ Curves data extracted
#    • Data type: <class 'numpy.ndarray'>
#    • Shape: (947,)
#    • Dtype: [('FRAMENO', '<i4'), (('T.CHANNEL-I.TDEP-O.1-C.0', 'TDEP'), '<f8'), (('T.CHANNEL-I.BIT-O.1-C.0', 'BIT'), '<f4'), (('T.CHANNEL-I.BVOL-O.1-C.0', 'BVOL'), '<f4'), (('T.CHANNEL-I.CALZ-O.1-C.0', 'CALZ'), '<f4'), (('T.CHANNEL-I.CN-O.1-C.0', 'CN'), '<f4'), (('T.CHANNEL-I.CNC-O.1-C.0', 'CNC'), '<f4'), (('T.CHANNEL-I.CVOL-O.1-C.0', 'CVOL'), '<f4'), (('T.CHANNEL-I.GR-O.1-C.0', 'GR'), '<f4'), (('T.CHANNEL-I.GRSL-O.1-C.0', 'GRSL'), '<f4'), (('T.CHANNEL-I.HRD1-O.1-C.0', 'HRD1'), '<f4'), (('T.CHANNEL-I.HRD2-O.1-C.0', 'HRD2'), '<f4'), (('T.CHANNEL-I.K-O.1-C.0', 'K'), '<f4'), (('T.CHANNEL-I.KTH-O.1-C.0', 'KTH'), '<f4'), (('T.CHANNEL-I.LSN-O.1-C.0', 'LSN'), '<f4'), (('T.CHANNEL-I.PE-O.1-C.0', 'PE'), '<f4'), (('T.CHANNEL-I.QPKS-O.1-C.0', 'QPKS'), '<i2'), (('T.CHANNEL-I.RTHK-O.1-C.0', 'RTHK'), '<f4'), (('T.CHANNEL-I.RTHU-O.1-C.0', 'RTHU'), '<f4'), (('T.CHANNEL-I.RUK-O.1-C.0', 'RUK'), '<f4'), (('T.CHANNEL-I.SFT2-O.1-C.0', 'SFT2'), '<f4'), (('T.CHANNEL-I.SHR-O.1-C.0', 'SHR'), '<f4'), (('T.CHANNEL-I.SLGN-O.1-C.0', 'SLGN'), '<f4'), (('T.CHANNEL-I.SLSP-O.1-C.0', 'SLSP'), '<f4', (254,)), (('T.CHANNEL-I.SLSPQ0-O.1-C.0', 'SLSPQ0'), '<u2', (254,)), (('T.CHANNEL-I.SLTM-O.1-C.0', 'SLTM'), '<f4'), (('T.CHANNEL-I.SPD-O.1-C.0', 'SPD'), '<f4'), (('T.CHANNEL-I.SSD-O.1-C.0', 'SSD'), '<f4'), (('T.CHANNEL-I.SSN-O.1-C.0', 'SSN'), '<f4'), (('T.CHANNEL-I.TEN-O.1-C.0', 'TEN'), '<f4'), (('T.CHANNEL-I.TH-O.1-C.0', 'TH'), '<f4'), (('T.CHANNEL-I.TTEN-O.1-C.0', 'TTEN'), '<f4'), (('T.CHANNEL-I.U-O.1-C.0', 'U'), '<f4'), (('T.CHANNEL-I.ZCOR-O.1-C.0', 'ZCOR'), '<f4'), (('T.CHANNEL-I.ZDEN-O.1-C.0', 'ZDEN'), '<f4'), (('T.CHANNEL-I.ZDNC-O.1-C.0', 'ZDNC'), '<f4')]
# ✅ Found 36 data fields
#
# 🔍 STEP 6: FIELD MAPPING
# ========================================
#    ✅ FRAMENO: 947 samples
#    ✅ TDEP: 947 samples
#    ✅ BIT: 947 samples
#    ✅ BVOL: 947 samples
#    ✅ CALZ: 947 samples
#    ✅ CN: 947 samples
#    ✅ CNC: 947 samples
#    ✅ CVOL: 947 samples
#    ✅ GR: 947 samples
#    ✅ GRSL: 947 samples
#    ✅ HRD1: 947 samples
#    ✅ HRD2: 947 samples
#    ✅ K: 947 samples
#    ✅ KTH: 947 samples
#    ✅ LSN: 947 samples
#    ✅ PE: 947 samples
#    ✅ QPKS: 947 samples
#    ✅ RTHK: 947 samples
#    ✅ RTHU: 947 samples
#    ✅ RUK: 947 samples
#    ✅ SFT2: 947 samples
#    ✅ SHR: 947 samples
#    ✅ SLGN: 947 samples
#    ⚠️ Skipping multi-dimensional: SLSP (947, 254)
#    ⚠️ Skipping multi-dimensional: SLSPQ0 (947, 254)
#    ✅ SLTM: 947 samples
#    ✅ SPD: 947 samples
#    ✅ SSD: 947 samples
#    ✅ SSN: 947 samples
#    ✅ TEN: 947 samples
#    ✅ TH: 947 samples
#    ✅ TTEN: 947 samples
#    ✅ U: 947 samples
#    ✅ ZCOR: 947 samples
#    ✅ ZDEN: 947 samples
#    ✅ ZDNC: 947 samples
#
# 📊 MAPPING SUMMARY:
#    • Successfully mapped: 34 fields
#    • Skipped: 2 fields
#    • Skipped list: ['SLSP (multi-dim)', 'SLSPQ0 (multi-dim)']
#
# 🔍 STEP 7: DATAFRAME CREATION
# ========================================
# ✅ DataFrame created: (947, 34)
# ✅ Set TDEP as index
#    • Depth range: 14516.00 - 14752.50
# ✅ Final DataFrame: (947, 33)
# ✅ Loaded: 947 samples × 33 channels
#    Depth range: 14516.0 - 14752.5 ft
#
# 🔗 Concatenating 7 DataFrames...
# ⚠️ Found 19188 duplicate depths, removing...
# ✅ Final combined log: 25178 samples × 45 channels
#    Combined depth range: 10650.0 - 19136.0 ft
#
# 📊 LOADING SUMMARY:
# Files found: 62
# Successfully loaded: 7
# Failed to load: 0
# Final shape: (25178, 45)
# Depth range: 10650.0 - 19136.0 ft
# Available channels: ['BIT', 'BVOL', 'CALZ', 'CALZ1', 'CALZ2', 'CHT.I', 'CN', 'CNC', 'CVOL', 'FRAMENO', 'GR', 'GRSL', 'HRD1', 'HRD12', 'HRD2', 'K', 'KTH', 'LSN', 'PE', 'PE2', 'QPKS', 'RTHK', 'RTHU', 'RUK', 'SFT2', 'SFT22', 'SHR', 'SHR2', 'SLGN', 'SLTM', 'SPD', 'SSD', 'SSD2', 'SSN', 'TEN', 'TH', 'TTEN', 'U', 'WTBH', 'ZCOR', 'ZCOR2', 'ZDEN', 'ZDEN2', 'ZDNC', 'ZDNC2']
#              BIT  BVOL  CALZ  CALZ1  CALZ2   CHT.I          CN         CNC  \
# TDEP
# 10650.00   12.00   NaN   NaN    NaN    NaN     NaN   50.388222   46.016716
# 10650.25   12.00   NaN   NaN    NaN    NaN     NaN   51.322247   46.949982
# 10650.50   12.00   NaN   NaN    NaN    NaN     NaN   52.472614   48.105431
# 10650.75   12.00   NaN   NaN    NaN    NaN     NaN   53.505451   49.148567
# 10651.00   12.00   NaN   NaN    NaN    NaN     NaN   53.565109   49.207821
# ...          ...   ...   ...    ...    ...     ...         ...         ...
# 19134.00 -999.25   NaN   NaN    NaN    NaN -999.25 -999.250000 -999.250000
# 19134.50 -999.25   NaN   NaN    NaN    NaN -999.25 -999.250000 -999.250000
# 19135.00 -999.25   NaN   NaN    NaN    NaN -999.25 -999.250000 -999.250000
# 19135.50 -999.25   NaN   NaN    NaN    NaN -999.25 -999.250000 -999.250000
# 19136.00 -999.25   NaN   NaN    NaN    NaN -999.25 -999.250000 -999.250000
#
#           CVOL  FRAMENO  ...          TH         TTEN           U    WTBH  \
# TDEP                     ...
# 10650.00   NaN        1  ...    3.024863  4383.399414    0.259066     NaN
# 10650.25   NaN        2  ...    3.163477  4387.063965    0.284641     NaN
# 10650.50   NaN        3  ...    3.293651  4391.781738    0.302876     NaN
# 10650.75   NaN        4  ...    3.400888  4395.671387    0.314478     NaN
# 10651.00   NaN        5  ...    3.498562  4397.529785    0.322099     NaN
# ...        ...      ...  ...         ...          ...         ...     ...
# 19134.00   NaN     9639  ... -999.250000          NaN -999.250000 -999.25
# 19134.50   NaN     9640  ... -999.250000          NaN -999.250000 -999.25
# 19135.00   NaN     9641  ... -999.250000          NaN -999.250000 -999.25
# 19135.50   NaN     9642  ... -999.250000          NaN -999.250000 -999.25
# 19136.00   NaN     9643  ... -999.250000          NaN -999.250000 -999.25
#
#                 ZCOR     ZCOR2        ZDEN     ZDEN2        ZDNC     ZDNC2
# TDEP
# 10650.00   -1.048316 -1.020690    2.199538  2.208459    2.190785  2.199453
# 10650.25   -1.053843 -1.016716    2.181385  2.211883    2.172793  2.202846
# 10650.50   -1.056162 -1.010766    2.171753  2.220564    2.163249  2.211453
# 10650.75   -1.054782 -1.002663    2.171503  2.235335    2.163001  2.226102
# 10651.00   -1.049812 -0.992796    2.179741  2.255228    2.171164  2.245839
# ...              ...       ...         ...       ...         ...       ...
# 19134.00 -999.250000       NaN -999.250000       NaN -999.250000       NaN
# 19134.50 -999.250000       NaN -999.250000       NaN -999.250000       NaN
# 19135.00 -999.250000       NaN -999.250000       NaN -999.250000       NaN
# 19135.50 -999.250000       NaN -999.250000       NaN -999.250000       NaN
# 19136.00 -999.250000       NaN -999.250000       NaN -999.250000       NaN
#
# [25178 rows x 45 columns]

# %%
# You now have a complete log dataset:
print(f"📊 Final log data: {log_df.shape}")
print(f"📏 Depth coverage: {log_df.index.min():.1f} - {log_df.index.max():.1f} ft")
print(f"🔍 Available channels: {len(log_df.columns)} {list(log_df.columns)}")
# Out:
# 📊 Final log data: (25178, 45)
# 📏 Depth coverage: 10650.0 - 19136.0 ft
# 🔍 Available channels: 45 ['BIT', 'BVOL', 'CALZ', 'CALZ1', 'CALZ2', 'CHT.I', 'CN', 'CNC', 'CVOL', 'FRAMENO', 'GR', 'GRSL', 'HRD1', 'HRD12', 'HRD2', 'K', 'KTH', 'LSN', 'PE', 'PE2', 'QPKS', 'RTHK', 'RTHU', 'RUK', 'SFT2', 'SFT22', 'SHR', 'SHR2', 'SLGN', 'SLTM', 'SPD', 'SSD', 'SSD2', 'SSN', 'TEN', 'TH', 'TTEN', 'U', 'WTBH', 'ZCOR', 'ZCOR2', 'ZDEN', 'ZDEN2', 'ZDNC', 'ZDNC2']

# %% [markdown]
# # cleaning log

# %%
# -999.25 are usually null values inside dlis files
null_values = -999.25

# Replace -999.25 with NaN FIRST
log_df_clean = log_df.replace(null_values, np.nan)
log_df_clean
# Out:
#            BIT  BVOL  CALZ  CALZ1  CALZ2  CHT.I         CN        CNC  CVOL  \
# TDEP
# 10650.00  12.0   NaN   NaN    NaN    NaN    NaN  50.388222  46.016716   NaN
# 10650.25  12.0   NaN   NaN    NaN    NaN    NaN  51.322247  46.949982   NaN
# 10650.50  12.0   NaN   NaN    NaN    NaN    NaN  52.472614  48.105431   NaN
# 10650.75  12.0   NaN   NaN    NaN    NaN    NaN  53.505451  49.148567   NaN
# 10651.00  12.0   NaN   NaN    NaN    NaN    NaN  53.565109  49.207821   NaN
# ...        ...   ...   ...    ...    ...    ...        ...        ...   ...
# 19134.00   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19134.50   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19135.00   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19135.50   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19136.00   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
#
#           FRAMENO  ...        TH         TTEN         U  WTBH      ZCOR  \
# TDEP               ...
# 10650.00        1  ...  3.024863  4383.399414  0.259066   NaN -1.048316
# 10650.25        2  ...  3.163477  4387.063965  0.284641   NaN -1.053843
# 10650.50        3  ...  3.293651  4391.781738  0.302876   NaN -1.056162
# 10650.75        4  ...  3.400888  4395.671387  0.314478   NaN -1.054782
# 10651.00        5  ...  3.498562  4397.529785  0.322099   NaN -1.049812
# ...           ...  ...       ...          ...       ...   ...       ...
# 19134.00     9639  ...       NaN          NaN       NaN   NaN       NaN
# 19134.50     9640  ...       NaN          NaN       NaN   NaN       NaN
# 19135.00     9641  ...       NaN          NaN       NaN   NaN       NaN
# 19135.50     9642  ...       NaN          NaN       NaN   NaN       NaN
# 19136.00     9643  ...       NaN          NaN       NaN   NaN       NaN
#
#              ZCOR2      ZDEN     ZDEN2      ZDNC     ZDNC2
# TDEP
# 10650.00 -1.020690  2.199538  2.208459  2.190785  2.199453
# 10650.25 -1.016716  2.181385  2.211883  2.172793  2.202846
# 10650.50 -1.010766  2.171753  2.220564  2.163249  2.211453
# 10650.75 -1.002663  2.171503  2.235335  2.163001  2.226102
# 10651.00 -0.992796  2.179741  2.255228  2.171164  2.245839
# ...            ...       ...       ...       ...       ...
# 19134.00       NaN       NaN       NaN       NaN       NaN
# 19134.50       NaN       NaN       NaN       NaN       NaN
# 19135.00       NaN       NaN       NaN       NaN       NaN
# 19135.50       NaN       NaN       NaN       NaN       NaN
# 19136.00       NaN       NaN       NaN       NaN       NaN
#
# [25178 rows x 45 columns]

# %%
# DEPTH ANALYSIS: Compare sampling characteristics between log and lab data
print("=" * 50)

print("Log depths summary:")
print(f"Count: {len(log_df_clean.index)}")  
print(f"Range: {log_df_clean.index.min():.1f} - {log_df_clean.index.max():.1f} ft\n")  
log_step = np.diff(log_df_clean.index).mean()  
print(f"Depth step (mean): {log_step:.2f} ft \nMin Step: {np.diff(log_df_clean.index).min():.2f} \nMax Step: {np.diff(log_df_clean.index).max():.2f}")  


print("=" * 50)


print("Lab depths summary:")
print(f"Count: {len(lab_data.index)}") 
print(f"Range: {lab_data.index.min():.1f} - {lab_data.index.max():.1f} ft\n")  
lab_step = np.diff(lab_data.index).mean()  
print(f"Depth step (mean): {lab_step:.2f} ft \nMin Step: {np.diff(lab_data.index).min():.2f} \nMax Step: {np.diff(lab_data.index).max():.2f}")
# Out:
# ==================================================
# Log depths summary:
# Count: 25178
# Range: 10650.0 - 19136.0 ft
#
# Depth step (mean): 0.34 ft
# Min Step: 0.25
# Max Step: 0.50
# ==================================================
# Lab depths summary:
# Count: 10
# Range: 14889.2 - 14938.5 ft
#
# Depth step (mean): 5.48 ft
# Min Step: 0.60
# Max Step: 25.80

# %% [markdown]
# # Log MISSING DATA SUMMARY

# %%
#Missing Data Summary for log data
# Calculate missingness summary
null_pct = log_df_clean.isna().mean() * 100

# Show all columns with their percentages
missing_cols = null_pct.sort_values(ascending=False)

# Show aggregate summary statistics for many columns
print("🔍 MISSING DATA SUMMARY:")
print("=" * 50)
print(f"Log DATASET: {log_df_clean.shape[0]} samples × {log_df_clean.shape[1]} curves")

print(f"Total columns: {len(null_pct)}")
print(f"Columns with missing data: {len(missing_cols)}")
print(f"Max missing %: {null_pct.max():.1f}%")
print(f"Avg missing %: {null_pct.mean():.1f}%")

# Quick check for duplicates
# print("\n🔍 DUPLICATE DEPTH CHECK:")
# print(f"Log duplicates: {log_df_clean.index.duplicated().sum()}")
# print(f"Lab duplicates: {lab_data.index.duplicated().sum()}")

# # Show unique vs total counts
# print(f"\nLog depths - Total: {len(log_df_clean)}, Unique: {log_df_clean.index.nunique()}")
# print(f"Lab depths - Total: {len(lab_data)}, Unique: {lab_data.index.nunique()}")

print("=" * 50)


# Show detailed breakdown for all columns
for col, pct in missing_cols.items():
    count = log_df_clean[col].isna().sum()
    print(f"• {col:<20}: {pct:>6.1f}% ({count} missing)")
# Out:
# 🔍 MISSING DATA SUMMARY:
# ==================================================
# Log DATASET: 25178 samples × 45 curves
# Total columns: 45
# Columns with missing data: 45
# Max missing %: 100.0%
# Avg missing %: 25.2%
# ==================================================
# • WTBH                :  100.0% (25178 missing)
# • CALZ                :   98.0% (24686 missing)
# • BVOL                :   97.2% (24462 missing)
# • CVOL                :   97.2% (24462 missing)
# • CALZ1               :   70.9% (17842 missing)
# • CALZ2               :   70.7% (17797 missing)
# • CHT.I               :   64.1% (16135 missing)
# • HRD2                :   62.6% (15774 missing)
# • ZDEN2               :   39.0% (9819 missing)
# • PE2                 :   39.0% (9819 missing)
# • ZDNC2               :   39.0% (9819 missing)
# • ZCOR2               :   39.0% (9819 missing)
# • HRD12               :   39.0% (9818 missing)
# • SFT22               :   39.0% (9818 missing)
# • SHR2                :   39.0% (9818 missing)
# • SSD2                :   39.0% (9813 missing)
# • SPD                 :   36.0% (9072 missing)
# • TEN                 :   36.0% (9071 missing)
# • TTEN                :   36.0% (9071 missing)
# • KTH                 :    2.6% (653 missing)
# • RTHK                :    2.6% (653 missing)
# • U                   :    2.6% (653 missing)
# • TH                  :    2.6% (653 missing)
# • RTHU                :    2.6% (653 missing)
# • RUK                 :    2.6% (653 missing)
# • K                   :    2.6% (653 missing)
# • GR                  :    2.5% (632 missing)
# • GRSL                :    2.5% (627 missing)
# • SLGN                :    2.4% (615 missing)
# • SLTM                :    2.4% (613 missing)
# • CNC                 :    2.2% (564 missing)
# • LSN                 :    2.2% (564 missing)
# • CN                  :    2.2% (564 missing)
# • SSN                 :    2.2% (564 missing)
# • ZDEN                :    1.9% (473 missing)
# • ZDNC                :    1.9% (473 missing)
# • ZCOR                :    1.9% (473 missing)
# • PE                  :    1.9% (473 missing)
# • SFT2                :    1.9% (470 missing)
# • HRD1                :    1.9% (470 missing)
# • SHR                 :    1.9% (470 missing)
# • SSD                 :    1.8% (455 missing)
# • BIT                 :    0.1% (14 missing)
# • FRAMENO             :    0.0% (0 missing)
# • QPKS                :    0.0% (0 missing)

# %% [markdown]
# # OVERLAP

# %%
# OVERLAP ZONE ANALYSIS: Identify common depth intervals for data integration
print("🔍 DETAILED OVERLAP ZONE ANALYSIS:")
print("=" * 50)

# Dataset coverage comparison
print(f"📏 Depth Ranges:")
print(f"Log Range: {log_df.index.min():.1f} - {log_df.index.max():.1f} ft")  
print(f"Lab Range: {lab_data.index.min():.1f} - {lab_data.index.max():.1f} ft")  

# Calculate overlap zone boundaries
overlap_start = max(lab_data.index.min(), log_df_clean.index.min())
overlap_end = min(lab_data.index.max(), log_df_clean.index.max())
overlap_span = overlap_end - overlap_start

print("=" * 50)

print(f"Overlap Range: {overlap_start:.1f} - {overlap_end:.1f} ft")
print(f"Span of overlap: {overlap_span:.1f} ft")

# Coverage percentages
lab_total_span = lab_data.index.max() - lab_data.index.min()
log_total_span = log_df_clean.index.max() - log_df_clean.index.min()
overlap_lab_pct = (overlap_span / lab_total_span) * 100
overlap_log_pct = (overlap_span / log_total_span) * 100

print(f"Coverage: {overlap_lab_pct:.1f}% of lab data, {overlap_log_pct:.1f}% of log data")
print("=" * 50)

# Get samples in overlap zone
log_overlap = log_df_clean[(log_df_clean.index >= overlap_start) & (log_df_clean.index <= overlap_end)]
lab_overlap = lab_data[(lab_data.index >= overlap_start) & (lab_data.index <= overlap_end)]

# Calculate Step statistics in overlap zone
if len(log_overlap) > 1:
    log_step_overlap = np.diff(log_overlap.index)
    print(f"LOG STEP IN OVERLAP:")
    print(f"Step (mean): {log_step_overlap.mean():.2f} ft")
    print(f"Min: {log_step_overlap.min():.2f} ft \nStep Max: {log_step_overlap.max():.2f}")
    # print(f"Step Std: {log_step_overlap.std():.2f} ft")

if len(lab_overlap) > 1:
    lab_step_overlap = np.diff(lab_overlap.index)
    print(f"\nLAB STEP IN OVERLAP:")
    print(f"Step (mean): {lab_step_overlap.mean():.2f} ft")
    print(f"Min: {lab_step_overlap.min():.2f} ft \nStep Max: {lab_step_overlap.min():.2f}")
    # print(f"Step Std: {lab_step_overlap.std():.2f} ft")

print("=" * 50)

# Show actual depths in overlap zone
print(f"📍 SAMPLE DEPTHS IN OVERLAP ZONE:")
print(f"🔵 Log depths (first/last 5 of {len(log_overlap):,}):")
if len(log_overlap) > 0:
    # Show first 5
    for i, depth in enumerate(log_overlap.index[:5]):
        print(f"   {i+1:2d}. {depth:.2f} ft")
    if len(log_overlap) > 10:
        print("   ...")
        # Show last 5
        for i, depth in enumerate(log_overlap.index[-5:], start=len(log_overlap)-4):
            print(f"  {i:2d}. {depth:.2f} ft")

print(f"🔴 Lab depths (all {len(lab_overlap)}):")
if len(lab_overlap) > 0:
    for i, depth in enumerate(lab_overlap.index):
        print(f"   {i+1:2d}. {depth:.1f} ft")

#display depths in a df
# Display lab_overlap and log_df_clean side by side for the overlap zone

print("Lab Overlap Samples:")
display(lab_overlap)

print("Log Data:")
display(log_df_clean.loc[log_df_clean.index])

# Data quality assessment for overlap zone
# print(f"\n⭐ OVERLAP ZONE ASSESSMENT:")
# if overlap_span >= 100:
#     print(f"✅ Overlap span: EXCELLENT ({overlap_span:.1f} ft)")
# elif overlap_span >= 50:
#     print(f"⚠️ Overlap span: GOOD ({overlap_span:.1f} ft)")
# else:
#     print(f"❌ Overlap span: POOR ({overlap_span:.1f} ft)")

# if len(lab_overlap) >= 5:
#     print(f"✅ Lab samples: SUFFICIENT ({len(lab_overlap)} samples)")
# elif len(lab_overlap) >= 3:
#     print(f"⚠️ Lab samples: LIMITED ({len(lab_overlap)} samples)")
# else:
#     print(f"❌ Lab samples: INSUFFICIENT ({len(lab_overlap)} samples)")

# if len(log_overlap) >= 100:
#     print(f"✅ Log samples: EXCELLENT ({len(log_overlap):,} samples)")
# elif len(log_overlap) >= 50:
#     print(f"⚠️ Log samples: GOOD ({len(log_overlap)} samples)")
# else:
#     print(f"❌ Log samples: POOR ({len(log_overlap)} samples)")

# Recommendations based on overlap analysis
# print(f"\n💡 OVERLAP RECOMMENDATIONS:")
# if overlap_span < 50:
#     print(f"Consider requesting more lab samples in {overlap_start:.0f}-{overlap_end:.0f} ft zone")
# if len(lab_overlap) < 3:
#     print(f"Minimum 3-5 lab samples needed for reliable")
# if overlap_log_pct < 20:
#     print(f"Overlap covers only {overlap_log_pct:.1f}% of log data - limited analysis scope")
# if overlap_lab_pct < 50:
#     print(f"Consider expanding log coverage to match lab sampling range")

# print(f"\n📊 INTEGRATION POTENTIAL:")
# integration_score = (min(overlap_span/100, 1) * 0.4 + 
#                     min(len(lab_overlap)/5, 1) * 0.3 + 
#                     min(len(log_overlap)/100, 1) * 0.3) * 100

# if integration_score >= 80:
#     print(f"🟢 EXCELLENT ({integration_score:.0f}/100) - Ready for comprehensive analysis")
# elif integration_score >= 60:
#     print(f"🟡 GOOD ({integration_score:.0f}/100) - Suitable for targeted analysis")
# else:
#     print(f"🔴 POOR ({integration_score:.0f}/100) - Limited analysis potential")
# Out:
# 🔍 DETAILED OVERLAP ZONE ANALYSIS:
# ==================================================
# 📏 Depth Ranges:
# Log Range: 10650.0 - 19136.0 ft
# Lab Range: 14889.2 - 14938.5 ft
# ==================================================
# Overlap Range: 14889.2 - 14938.5 ft
# Span of overlap: 49.3 ft
# Coverage: 100.0% of lab data, 0.6% of log data
# ==================================================
# LOG STEP IN OVERLAP:
# Step (mean): 0.50 ft
# Min: 0.50 ft
# Step Max: 0.50
#
# LAB STEP IN OVERLAP:
# Step (mean): 5.48 ft
# Min: 0.60 ft
# Step Max: 0.60
# ==================================================
# 📍 SAMPLE DEPTHS IN OVERLAP ZONE:
# 🔵 Log depths (first/last 5 of 99):
#     1. 14889.50 ft
#     2. 14890.00 ft
#     3. 14890.50 ft
#     4. 14891.00 ft
#     5. 14891.50 ft
#    ...
#   95. 14936.50 ft
#   96. 14937.00 ft
#   97. 14937.50 ft
#   98. 14938.00 ft
#   99. 14938.50 ft
# 🔴 Lab depths (all 10):
#     1. 14889.2 ft
#     2. 14893.8 ft
#     3. 14894.7 ft
#     4. 14895.3 ft
#     5. 14901.9 ft
#     6. 14903.7 ft
#     7. 14905.7 ft
#     8. 14931.5 ft
#     9. 14932.4 ft
#    10. 14938.5 ft
# Lab Overlap Samples:
#           Sample_ID  XRD_Calcite  XRD_Dolomite  XRD_Ankerite  XRD_Siderite  \
# Depth_ft
# 14889.2           2            0             0             0             0
# 14893.8           3            0             0             0             0
# 14894.7           4            0             0             0             0
# 14895.3           5            0             0             0             0
# 14901.9           6            0             0             0             0
# 14903.7           7            0             0             0             0
# 14905.7           8            0             0             0             0
# 14931.5          14            0             0             0             0
# 14932.4          15            0             0             0             0
# 14938.5          17            0             0             0             0
#
#           XRD_Quartz  XRD_Plagioclase  XRD_K-Feldspar  XRD_Illite/Mica  \
# Depth_ft
# 14889.2         99.2                0             0.0              0.7
# 14893.8         96.1                0             0.0              3.8
# 14894.7         96.5                0             0.0              3.4
# 14895.3         95.1                0             0.0              4.8
# 14901.9         96.7                0             0.9              2.0
# 14903.7         97.4                0             0.0              2.5
# 14905.7         94.0                0             0.0              5.9
# 14931.5         92.0                0             0.0              7.9
# 14932.4         95.0                0             0.0              4.9
# 14938.5         95.0                0             0.0              4.9
#
#           XRD_Smectite  ...  XRF_S  XRF_Cl  XRF_K  XRF_Ca  XRF_Ti  XRF_Mn  \
# Depth_ft                ...
# 14889.2              0  ...   0.11    0.69   2.74    1.19    0.00       0
# 14893.8              0  ...   0.00    1.25   5.30    1.48    0.25       0
# 14894.7              0  ...   0.56    1.01   4.23    3.07    0.37       0
# 14895.3              0  ...   0.11    1.14   6.24    1.19    0.70       0
# 14901.9              0  ...   0.64    1.03   4.05    3.24    0.68       0
# 14903.7              0  ...   0.00    0.96   4.10    0.94    0.65       0
# 14905.7              0  ...   0.00    1.11   7.96    1.34    0.83       0
# 14931.5              0  ...   0.15    1.33   5.96    1.68    0.86       0
# 14932.4              0  ...   0.00    2.05   4.86    1.87    0.44       0
# 14938.5              0  ...   0.33    1.51   8.44    2.99    1.76       0
#
#           XRF_Fe  XRF_Zr  XRF_Sr  XRF_Ba
# Depth_ft
# 14889.2     0.59    0.14    0.00       0
# 14893.8     1.14    0.08    0.00       0
# 14894.7     0.98    0.08    0.00       0
# 14895.3     1.72    0.17    0.00       0
# 14901.9     1.68    0.22    0.00       0
# 14903.7     0.80    0.16    0.00       0
# 14905.7     1.63    0.00    0.04       0
# 14931.5     1.76    0.14    0.00       0
# 14932.4     1.48    0.10    0.00       0
# 14938.5     3.52    0.10    0.24       0
#
# [10 rows x 32 columns]
# Log Data:
#            BIT  BVOL  CALZ  CALZ1  CALZ2  CHT.I         CN        CNC  CVOL  \
# TDEP
# 10650.00  12.0   NaN   NaN    NaN    NaN    NaN  50.388222  46.016716   NaN
# 10650.25  12.0   NaN   NaN    NaN    NaN    NaN  51.322247  46.949982   NaN
# 10650.50  12.0   NaN   NaN    NaN    NaN    NaN  52.472614  48.105431   NaN
# 10650.75  12.0   NaN   NaN    NaN    NaN    NaN  53.505451  49.148567   NaN
# 10651.00  12.0   NaN   NaN    NaN    NaN    NaN  53.565109  49.207821   NaN
# ...        ...   ...   ...    ...    ...    ...        ...        ...   ...
# 19134.00   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19134.50   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19135.00   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19135.50   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
# 19136.00   NaN   NaN   NaN    NaN    NaN    NaN        NaN        NaN   NaN
#
#           FRAMENO  ...        TH         TTEN         U  WTBH      ZCOR  \
# TDEP               ...
# 10650.00        1  ...  3.024863  4383.399414  0.259066   NaN -1.048316
# 10650.25        2  ...  3.163477  4387.063965  0.284641   NaN -1.053843
# 10650.50        3  ...  3.293651  4391.781738  0.302876   NaN -1.056162
# 10650.75        4  ...  3.400888  4395.671387  0.314478   NaN -1.054782
# 10651.00        5  ...  3.498562  4397.529785  0.322099   NaN -1.049812
# ...           ...  ...       ...          ...       ...   ...       ...
# 19134.00     9639  ...       NaN          NaN       NaN   NaN       NaN
# 19134.50     9640  ...       NaN          NaN       NaN   NaN       NaN
# 19135.00     9641  ...       NaN          NaN       NaN   NaN       NaN
# 19135.50     9642  ...       NaN          NaN       NaN   NaN       NaN
# 19136.00     9643  ...       NaN          NaN       NaN   NaN       NaN
#
#              ZCOR2      ZDEN     ZDEN2      ZDNC     ZDNC2
# TDEP
# 10650.00 -1.020690  2.199538  2.208459  2.190785  2.199453
# 10650.25 -1.016716  2.181385  2.211883  2.172793  2.202846
# 10650.50 -1.010766  2.171753  2.220564  2.163249  2.211453
# 10650.75 -1.002663  2.171503  2.235335  2.163001  2.226102
# 10651.00 -0.992796  2.179741  2.255228  2.171164  2.245839
# ...            ...       ...       ...       ...       ...
# 19134.00       NaN       NaN       NaN       NaN       NaN
# 19134.50       NaN       NaN       NaN       NaN       NaN
# 19135.00       NaN       NaN       NaN       NaN       NaN
# 19135.50       NaN       NaN       NaN       NaN       NaN
# 19136.00       NaN       NaN       NaN       NaN       NaN
#
# [25178 rows x 45 columns]

# %% [markdown]
# # join

# %%
from scipy.spatial import cKDTree
import numpy as np
import pandas as pd
from Module import match_lab_to_log

tolerance_ft = 1

joined = match_lab_to_log(log_df_clean, lab_overlap, tol=tolerance_ft)

if len(joined) > 0:
    print(f"\n✅ Found {len(joined)} matches with {tolerance_ft} ft tolerance")
    
    # Show statistics
    print(f"\nMATCH STATISTICS:")
    print(f"Average distance: {joined['Distance'].mean():.3f} ft")
    print(f"Max distance: {joined['Distance'].max():.3f} ft")
    print(f"Exact matches: {(joined['Distance'] == 0).sum()}")
    print(f"Near matches: {(joined['Distance'] > 0).sum()}")
    
    # Save results for verification
    verification_df = joined[['Lab_Depth', 'Log_Depth', 'Distance']].copy()
    verification_df.to_csv('verification_matches.csv', index=False)
    print(f"\n💾 Saved verification data to 'verification_matches.csv'")
    
else:
    print(f"\n❌ No matches found with {tolerance_ft} ft tolerance")
    print("Trying with larger tolerance...")
    
    # Try with diffrent ft tolerance
    joined = match_lab_to_log(log_df_clean, lab_overlap, tol=1)

joined
# Out:
# FUNCTION START - INPUT VALIDATION:
# Log DataFrame shape: (25178, 45)
# Lab DataFrame shape: (10, 32)
# After deduplication - Log: 25178, Lab: 10
# Lab depths range: 14889.20 - 14938.50
# Log depths range: 10650.00 - 19136.00
# Tolerance: 1 ft
# Valid matches found: 10/10
# Min distance: 0.00 ft
# Max distance: 0.20 ft
#
# MATCH VERIFICATION:
#    Match 1: Lab 14889.20 → Log 14889.00 (Δ0.20 ft)
#    Match 2: Lab 14893.80 → Log 14894.00 (Δ0.20 ft)
#    Match 3: Lab 14894.70 → Log 14894.50 (Δ0.20 ft)
#    Match 4: Lab 14895.30 → Log 14895.50 (Δ0.20 ft)
#    Match 5: Lab 14901.90 → Log 14902.00 (Δ0.10 ft)
#    Match 6: Lab 14903.70 → Log 14903.50 (Δ0.20 ft)
#    Match 7: Lab 14905.70 → Log 14905.50 (Δ0.20 ft)
#    Match 8: Lab 14931.50 → Log 14931.50 (Δ0.00 ft)
#    Match 9: Lab 14932.40 → Log 14932.50 (Δ0.10 ft)
#    Match 10: Lab 14938.50 → Log 14938.50 (Δ0.00 ft)
# Matched samples extracted: 10 pairs
#
# ✅ Found 10 matches with 1 ft tolerance
#
# MATCH STATISTICS:
# Average distance: 0.140 ft
# Max distance: 0.200 ft
# Exact matches: 2
# Near matches: 8
#
# 💾 Saved verification data to 'verification_matches.csv'
#    Lab_Depth  Lab_Sample_ID  Lab_XRD_Calcite  Lab_XRD_Dolomite  \
# 0    14889.2              2                0                 0
# 1    14893.8              3                0                 0
# 2    14894.7              4                0                 0
# 3    14895.3              5                0                 0
# 4    14901.9              6                0                 0
# 5    14903.7              7                0                 0
# 6    14905.7              8                0                 0
# 7    14931.5             14                0                 0
# 8    14932.4             15                0                 0
# 9    14938.5             17                0                 0
#
#    Lab_XRD_Ankerite  Lab_XRD_Siderite  Lab_XRD_Quartz  Lab_XRD_Plagioclase  \
# 0                 0                 0            99.2                    0
# 1                 0                 0            96.1                    0
# 2                 0                 0            96.5                    0
# 3                 0                 0            95.1                    0
# 4                 0                 0            96.7                    0
# 5                 0                 0            97.4                    0
# 6                 0                 0            94.0                    0
# 7                 0                 0            92.0                    0
# 8                 0                 0            95.0                    0
# 9                 0                 0            95.0                    0
#
#    Lab_XRD_K-Feldspar  Lab_XRD_Illite/Mica  ...      Log_U  Log_WTBH  \
# 0                 0.0                  0.7  ...   8.852848       NaN
# 1                 0.0                  3.8  ...   8.081790       NaN
# 2                 0.0                  3.4  ...   8.290098       NaN
# 3                 0.0                  4.8  ...   9.072144       NaN
# 4                 0.9                  2.0  ...   8.525779       NaN
# 5                 0.0                  2.5  ...   9.923880       NaN
# 6                 0.0                  5.9  ...  10.382340       NaN
# 7                 0.0                  7.9  ...   8.952220       NaN
# 8                 0.0                  4.9  ...  10.230805       NaN
# 9                 0.0                  4.9  ...   9.860523       NaN
#
#    Log_ZCOR  Log_ZCOR2  Log_ZDEN  Log_ZDEN2  Log_ZDNC  Log_ZDNC2  Distance  \
# 0 -0.065304        NaN  2.501206        NaN  2.490906        NaN       0.2
# 1 -0.088089        NaN  2.434864        NaN  2.424978        NaN       0.2
# 2 -0.080392        NaN  2.451017        NaN  2.441028        NaN       0.2
# 3 -0.049249        NaN  2.506464        NaN  2.496131        NaN       0.2
# 4 -0.042403        NaN  2.498839        NaN  2.488553        NaN       0.1
# 5 -0.044524        NaN  2.493208        NaN  2.482956        NaN       0.2
# 6 -0.032361        NaN  2.427736        NaN  2.417896        NaN       0.2
# 7 -0.059618        NaN  2.473074        NaN  2.462947        NaN       0.0
# 8 -0.062772        NaN  2.478785        NaN  2.468622        NaN       0.1
# 9 -0.011614        NaN  2.532634        NaN  2.522145        NaN       0.0
#
#    Match_Type
# 0        Near
# 1        Near
# 2        Near
# 3        Near
# 4        Near
# 5        Near
# 6        Near
# 7       Exact
# 8        Near
# 9       Exact
#
# [10 rows x 81 columns]

# %% [markdown]
# # DATA INTEGRATION ASSESSMENT

# %%
# COMPREHENSIVE DATA INTEGRATION ASSESSMENT
print("COMPREHENSIVE DATA INTEGRATION ASSESSMENT")
print("=" * 60)

# 1. Basic Statistics
lab_coverage = (len(joined) / len(lab_data)) * 100
log_coverage = (len(joined) / len(log_df_clean)) * 100

lab_span = lab_data.index.max() - lab_data.index.min()
log_span = log_df_clean.index.max() - log_df_clean.index.min()

matched_span = joined['Lab_Depth'].max() - joined['Lab_Depth'].min()
avg_depth_diff = abs(joined['Log_Depth'] - joined['Lab_Depth']).mean()

print(f"📊 DATA OVERVIEW:")
print(f"   • Lab samples: {len(lab_data)} | Log samples: {len(log_df_clean)}")
print(f"   • Matched pairs: {len(joined)}")
# print(f"   • Data ratio: 1 lab sample per {len(log_df_clean)//len(lab_data)} log samples") not usful

# 2. Coverage Analysis
print(f"\n📈 COVERAGE ANALYSIS:")
print(f"   • Lab utilization: {lab_coverage:.1f}% ({len(joined)}/{len(lab_data)})")
print(f"   • Log coverage: {log_coverage:.1f}% ({len(joined)}/{len(log_df_clean)})")

# 3. Depth Range Analysis
print(f"\n📏 DEPTH RANGE ANALYSIS:")
print(f"   • Lab data span: {lab_span:.1f} ft")
print(f"   • Log data span: {log_span:.1f} ft")
print(f"   • Matched (joined) span: {matched_span:.1f} ft")
print(f"   • Lab covers {(lab_span/log_span)*100:.1f}% of well depth")

# 4. Depth Accuracy
print(f"\n🎯 DEPTH ACCURACY:")
print(f"   • Average depth difference: {avg_depth_diff:.2f} ft")
print(f"   • Max depth difference: {abs(joined['Log_Depth'] - joined['Lab_Depth']).max():.2f} ft")
print(f"   • Min depth difference: {abs(joined['Log_Depth'] - joined['Lab_Depth']).min():.2f} ft")


# 6. Overlap Analysis
overlap_start = max(lab_data.index.min(), log_df_clean.index.min())
overlap_end = min(lab_data.index.max(), log_df_clean.index.max())
overlap_span = overlap_end - overlap_start
print(f"\n🔄 OVERLAP ZONE ANALYSIS:")
print(f"Overlap zone: {overlap_start:.1f} - {overlap_end:.1f} ft")

# Get samples in overlap zone - FIXED the bug
log_overlap = joined[(joined.index >= overlap_start) & (joined.index <= overlap_end)]
lab_overlap = lab_data[(lab_data.index >= overlap_start) & (lab_data.index <= overlap_end)]

print(f"Log samples in overlap: {len(log_overlap)}")
print(f"Lab samples in overlap: {len(lab_overlap)}")



# 7. Quality Assessment
print(f"\n⭐ QUALITY ASSESSMENT:")
if lab_coverage >= 80:
    print(f"   ✅ Lab utilization: EXCELLENT ({lab_coverage:.1f}%)")
elif lab_coverage >= 60:
    print(f"   ⚠️ Lab utilization: GOOD ({lab_coverage:.1f}%)")
else:
    print(f"   ❌ Lab utilization: POOR ({lab_coverage:.1f}%)")


if avg_depth_diff <= 1:
    print(f"   ✅ Depth accuracy: EXCELLENT ({avg_depth_diff:.2f} ft)")
elif avg_depth_diff <= 2:
    print(f"   ⚠️ Depth accuracy: GOOD ({avg_depth_diff:.2f} ft)")
else:
    print(f"   ❌ Depth accuracy: POOR ({avg_depth_diff:.2f} ft)")

# 8. Overall Assessment
excellent_count = sum([lab_coverage >= 80, log_coverage >= 50, matched_span >= 100, avg_depth_diff <= 1])
good_count = sum([60 <= lab_coverage < 80, 20 <= log_coverage < 50, 50 <= matched_span < 100, 1 < avg_depth_diff <= 2])

print(f"\n🏆 OVERALL ASSESSMENT:")
if excellent_count >= 3:
    print(f"   ✅ EXCELLENT - Ready for comprehensive analysis")
elif excellent_count + good_count >= 3:
    print(f"   ⚠️ GOOD - Suitable for limited analysis")
else:
    print(f"   ❌ POOR - Needs improvement before analysis")



print(f"\n📝 SUMMARY: Lab utilization is {lab_coverage:.1f}%, but only {log_coverage:.1f}% log coverage.")
# Out:
# COMPREHENSIVE DATA INTEGRATION ASSESSMENT
# ============================================================
# 📊 DATA OVERVIEW:
#    • Lab samples: 10 | Log samples: 25178
#    • Matched pairs: 10
#
# 📈 COVERAGE ANALYSIS:
#    • Lab utilization: 100.0% (10/10)
#    • Log coverage: 0.0% (10/25178)
#
# 📏 DEPTH RANGE ANALYSIS:
#    • Lab data span: 49.3 ft
#    • Log data span: 8486.0 ft
#    • Matched (joined) span: 49.3 ft
#    • Lab covers 0.6% of well depth
#
# 🎯 DEPTH ACCURACY:
#    • Average depth difference: 0.14 ft
#    • Max depth difference: 0.20 ft
#    • Min depth difference: 0.00 ft
#
# 🔄 OVERLAP ZONE ANALYSIS:
# Overlap zone: 14889.2 - 14938.5 ft
# Log samples in overlap: 0
# Lab samples in overlap: 10
#
# ⭐ QUALITY ASSESSMENT:
#    ✅ Lab utilization: EXCELLENT (100.0%)
#    ✅ Depth accuracy: EXCELLENT (0.14 ft)
#
# 🏆 OVERALL ASSESSMENT:
#    ❌ POOR - Needs improvement before analysis
#
# 📝 SUMMARY: Lab utilization is 100.0%, but only 0.0% log coverage.

# %% [markdown]
# # Visualizations

# %%
# Visualize the quality of matches
plt.figure(figsize=(12, 6))

# Left plot: Distance histogram
plt.subplot(1, 2, 1)
sns.histplot(joined['Distance'], bins=20, kde=True)
plt.xlabel('Match Distance (ft)')
plt.ylabel('Frequency')
plt.title('Distribution of Match Distances')
plt.grid(True)

# Right plot: Match types
plt.subplot(1, 2, 2)
match_counts = joined['Match_Type'].value_counts()
plt.pie(match_counts, labels=match_counts.index, autopct='%1.1f%%', 
        colors=['#66b3ff', '#99ff99'], startangle=90)
plt.axis('equal')
plt.title('Match Type Distribution')

plt.tight_layout()
plt.savefig('match_quality.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Filter for all lab measurement columns (excluding non-measurement columns)
lab_vars = [col for col in joined.columns if col.startswith('Lab_') and 
           col not in ['Lab_Depth', 'Lab_Sample_ID']]

# Filter for all log measurement columns (excluding non-measurement or auxiliary columns)
log_vars = [col for col in joined.columns if col.startswith('Log_') and 
           col not in ['Log_Depth', 'Log_FRAMENO']]

# Filter out columns where all values are 0
lab_vars = [col for col in lab_vars if not (joined[col] == 0).all()]
log_vars = [col for col in log_vars if not joined[col].isnull().all()]

# 
print(len(lab_vars), "lab variables")
print("Lab variables:", lab_vars)
print(len(log_vars), "log variables")

# Compute correlation matrix (log variables as rows, lab variables as columns)
corr_matrix = joined[lab_vars + log_vars].corr().loc[log_vars, lab_vars]


# Create a larger figure 
plt.figure(figsize=(24, 24))

# Plot the heatmap 
sns.heatmap(corr_matrix, 
            annot=True,                  
            cmap='RdYlGn',               
            vmin=-1, vmax=1,             
            linewidths=0.5,              
            fmt='.2f',                   
            annot_kws={'size': 20},       
            cbar_kws={"shrink": 0.8})    
            
    
#  labeling and styling
plt.title('Correlation Between Log Measurements (y-axis) and Lab Measurements (x-axis)', fontsize=20)
plt.xticks(rotation=45, ha='right', fontsize=20)      
plt.yticks(fontsize=20)                   

# Add clearer axis labels
plt.xlabel('Lab Measurements', fontsize=25, )
plt.ylabel('Log Measurements', fontsize=25, )

plt.tight_layout()
plt.savefig('correlation_heatmap_comprehensive.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 17 lab variables
# Lab variables: ['Lab_XRD_Quartz', 'Lab_XRD_K-Feldspar', 'Lab_XRD_Illite/Mica', 'Lab_XRD_Chlorite', 'Lab_XRF_Na', 'Lab_XRF_Mg', 'Lab_XRF_Al', 'Lab_XRF_Si', 'Lab_XRF_P', 'Lab_XRF_S', 'Lab_XRF_Cl', 'Lab_XRF_K', 'Lab_XRF_Ca', 'Lab_XRF_Ti', 'Lab_XRF_Fe', 'Lab_XRF_Zr', 'Lab_XRF_Sr']
# 27 log variables

# %% [markdown]
# # stat

# %%
#  Extract all unique r’s (Pearson correlation coefficient)
vals = corr_matrix.values
mask = np.triu(np.ones_like(vals), k=1).astype(bool)
r_vals = vals[mask]

plt.figure(figsize=(6,4))
plt.hist(r_vals, bins=20)
plt.title("Distribution of Pearson-r Values")
plt.xlabel("r")
plt.ylabel("Frequency")
plt.show()

# %%
for var in log_vars + lab_vars:
    plt.figure(figsize=(5,3))
    sns.histplot(joined[var].dropna(), bins=30, kde=True, stat='count')
    plt.title(f"Distribution of {var}")
    plt.xlabel(var)
    plt.ylabel("Count")  
    plt.tight_layout()   
    plt.show()

# %%
# ► 1) Compute summary stats
stats = joined[log_vars + lab_vars].describe().T
stats['skew']    = joined[stats.index].skew()
stats['kurtosis']= joined[stats.index].kurtosis()

# ► b) Display top 10 for review
stats[['mean','50%','std','min','max','skew','kurtosis']]
# Out:
#                              mean           50%         std           min  \
# Log_BIT                  8.375000      8.375000    0.000000      8.375000
# Log_CHT.I             2055.014893   2049.081848   23.262007   2026.075317
# Log_CN                   5.481168      5.482461    1.104234      3.074240
# Log_CNC                  5.386183      5.387448    1.095447      2.998433
# Log_GR                  51.159122     50.416681    4.957025     45.374146
# Log_GRSL                51.293682     50.237906    6.367935     43.893738
# Log_HRD1               664.593628    655.110352   62.402878    577.999573
# Log_HRD2              1118.135986   1088.207397   75.857513   1030.691284
# Log_K                    0.306993      0.357334    0.226795      0.005622
# Log_KTH                 14.368216     12.619914    4.076355     10.170943
# Log_LSN               2304.844238   2258.751587  306.891785   1962.016602
# Log_PE                  11.632131     11.992992    1.033996      9.375854
# Log_QPKS                 2.000000      2.000000    0.000000      2.000000
# Log_RTHK               126.218102     10.841428  308.671082      8.393706
# Log_RTHU                 0.509111      0.529530    0.096347      0.314318
# Log_RUK                214.624268     25.163586  483.263824     15.403067
# Log_SFT2               324.221954    324.316788   51.391312    267.146576
# Log_SHR                  0.162309      0.153748    0.023240      0.133060
# Log_SLGN              2941.699951   2942.000000    0.483046   2941.000000
# Log_SLTM              1171.800049   1137.000000   93.767799   1082.000000
# Log_SSD              18687.822266  18698.476562  779.647827  17614.333984
# Log_SSN               3332.469971   3242.196045  224.919220   3109.511719
# Log_TH                   4.666574      4.543163    0.860883      3.099338
# Log_U                    9.217242      9.012182    0.826569      8.081790
# Log_ZCOR                -0.053633     -0.054434    0.022621     -0.088089
# Log_ZDEN                 2.479783      2.485997    0.033512      2.427736
# Log_ZDNC                 2.469616      2.475789    0.033304      2.417896
# Lab_XRD_Quartz          95.700000     95.600000    1.968079     92.000000
# Lab_XRD_K-Feldspar       0.090000      0.000000    0.284605      0.000000
# Lab_XRD_Illite/Mica      4.080000      4.300000    2.069783      0.700000
# Lab_XRD_Chlorite         0.130000      0.100000    0.094868      0.100000
# Lab_XRF_Na               0.185000      0.175000    0.049497      0.140000
# Lab_XRF_Mg               0.308000      0.280000    0.162809      0.110000
# Lab_XRF_Al               2.953000      2.985000    0.990534      1.390000
# Lab_XRF_Si              85.531000     85.690000    4.460143     76.190000
# Lab_XRF_P                0.007000      0.000000    0.014944      0.000000
# Lab_XRF_S                0.190000      0.110000    0.239861      0.000000
# Lab_XRF_Cl               1.208000      1.125000    0.369949      0.690000
# Lab_XRF_K                5.388000      5.080000    1.797268      2.740000
# Lab_XRF_Ca               1.899000      1.580000    0.870612      0.940000
# Lab_XRF_Ti               0.654000      0.665000    0.473385      0.000000
# Lab_XRF_Fe               1.530000      1.555000    0.813443      0.590000
# Lab_XRF_Zr               0.119000      0.120000    0.060818      0.000000
# Lab_XRF_Sr               0.028000      0.000000    0.075542      0.000000
#
#                               max      skew   kurtosis
# Log_BIT                  8.375000  0.000000   0.000000
# Log_CHT.I             2090.848633  0.562361  -0.921270
# Log_CN                   7.040384 -0.939853   1.747875
# Log_CNC                  6.933039 -0.939771   1.747759
# Log_GR                  61.146290  0.943294   0.466750
# Log_GRSL                62.925125  0.812412  -0.285136
# Log_HRD1               808.258423  1.243344   2.791032
# Log_HRD2              1294.190063  1.498391   2.572499
# Log_K                    0.599290 -0.122610  -1.704759
# Log_KTH                 21.323200  0.838762  -0.932892
# Log_LSN               3037.491943  1.626362   3.349594
# Log_PE                  12.959793 -1.145353   1.456728
# Log_QPKS                 2.000000  0.000000   0.000000
# Log_RTHK              1000.269531  3.104170   9.721468
# Log_RTHU                 0.635230 -0.730503   0.460669
# Log_RUK               1574.657104  3.036619   9.388152
# Log_SFT2               410.379883  0.404394  -1.111976
# Log_SHR                  0.214409  1.245791   1.924051
# Log_SLGN              2942.000000 -1.035098  -1.224490
# Log_SLTM              1326.000000  0.805693  -0.912637
# Log_SSD              20104.773438  0.503642  -0.169807
# Log_SSN               3779.937988  1.311206   0.697067
# Log_TH                   5.893412 -0.224603  -0.258519
# Log_U                   10.382340  0.142728  -1.547295
# Log_ZCOR                -0.011614  0.281152   0.073900
# Log_ZDEN                 2.532634 -0.258065  -0.743429
# Log_ZDNC                 2.522145 -0.257771  -0.743309
# Lab_XRD_Quartz          99.200000 -0.129432   0.842986
# Lab_XRD_K-Feldspar       0.900000  3.162278  10.000000
# Lab_XRD_Illite/Mica      7.900000  0.177836   0.188915
# Lab_XRD_Chlorite         0.400000  3.162278  10.000000
# Lab_XRF_Na               0.290000  1.157896   0.920489
# Lab_XRF_Mg               0.530000  0.201065  -1.890282
# Lab_XRF_Al               4.280000  0.042283  -1.167161
# Lab_XRF_Si              92.900000 -0.567555   1.761205
# Lab_XRF_P                0.040000  1.887601   2.158610
# Lab_XRF_S                0.640000  1.167451  -0.025132
# Lab_XRF_Cl               2.050000  1.254911   2.530736
# Lab_XRF_K                8.440000  0.513117  -0.403480
# Lab_XRF_Ca               3.240000  0.728710  -1.295250
# Lab_XRF_Ti               1.760000  1.294637   3.124153
# Lab_XRF_Fe               3.520000  1.666571   4.068447
# Lab_XRF_Zr               0.220000 -0.350135   0.756820
# Lab_XRF_Sr               0.240000  3.013716   9.231374
