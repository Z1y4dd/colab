# %%
from dlisio import dlis
import numpy as np
import pandas as pd
# from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import sklearn

pd.set_option('display.max_rows', 50)

# %% [markdown]
# # extracting lab

# %%
# loading lab_data from an Excel file
LAB_PATH = r"\\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\HRDH_LAB_DATA.xlsx"
sheet_name = 'HRDH_1111'
lab_data = pd.read_excel(LAB_PATH, sheet_name=sheet_name).set_index('Depth_ft')
lab_data
# Out:
#           Sample_ID  XRD_Calcite  XRD_Dolomite  XRD_Ankerite  XRD_Siderite  \
# Depth_ft
# 14889.2           2            0             0             0             0
# 14893.8           3            0             0             0             0
# 14894.7           4            0             0             0             0
# 14895.3           5            0             0             0             0
# 14901.9           6            0             0             0             0
# 14903.7           7            0             0             0             0
# 14905.7           8            0             0             0             0
# 14931.5          14            0             0             0             0
# 14932.4          15            0             0             0             0
# 14938.5          17            0             0             0             0
#
#           XRD_Quartz  XRD_Plagioclase  XRD_K-Feldspar  XRD_Illite/Mica  \
# Depth_ft
# 14889.2         99.2                0             0.0              0.7
# 14893.8         96.1                0             0.0              3.8
# 14894.7         96.5                0             0.0              3.4
# 14895.3         95.1                0             0.0              4.8
# 14901.9         96.7                0             0.9              2.0
# 14903.7         97.4                0             0.0              2.5
# 14905.7         94.0                0             0.0              5.9
# 14931.5         92.0                0             0.0              7.9
# 14932.4         95.0                0             0.0              4.9
# 14938.5         95.0                0             0.0              4.9
#
#           XRD_Smectite  ...  XRF_S  XRF_Cl  XRF_K  XRF_Ca  XRF_Ti  XRF_Mn  \
# Depth_ft                ...
# 14889.2              0  ...   0.11    0.69   2.74    1.19    0.00       0
# 14893.8              0  ...   0.00    1.25   5.30    1.48    0.25       0
# 14894.7              0  ...   0.56    1.01   4.23    3.07    0.37       0
# 14895.3              0  ...   0.11    1.14   6.24    1.19    0.70       0
# 14901.9              0  ...   0.64    1.03   4.05    3.24    0.68       0
# 14903.7              0  ...   0.00    0.96   4.10    0.94    0.65       0
# 14905.7              0  ...   0.00    1.11   7.96    1.34    0.83       0
# 14931.5              0  ...   0.15    1.33   5.96    1.68    0.86       0
# 14932.4              0  ...   0.00    2.05   4.86    1.87    0.44       0
# 14938.5              0  ...   0.33    1.51   8.44    2.99    1.76       0
#
#           XRF_Fe  XRF_Zr  XRF_Sr  XRF_Ba
# Depth_ft
# 14889.2     0.59    0.14    0.00       0
# 14893.8     1.14    0.08    0.00       0
# 14894.7     0.98    0.08    0.00       0
# 14895.3     1.72    0.17    0.00       0
# 14901.9     1.68    0.22    0.00       0
# 14903.7     0.80    0.16    0.00       0
# 14905.7     1.63    0.00    0.04       0
# 14931.5     1.76    0.14    0.00       0
# 14932.4     1.48    0.10    0.00       0
# 14938.5     3.52    0.10    0.24       0
#
# [10 rows x 32 columns]

# %%
# convert data types to float
lab_data = lab_data.apply(pd.to_numeric, errors='coerce')


print("\n📋 DATAFRAME STRUCTURE:")
print(f"Index: {lab_data.index.name} (shape: {lab_data.index.shape})")
print(f"Columns: {list(lab_data.columns)} (shape: {lab_data.shape})")
print(f"Data types:\n{lab_data.info()}\n")
# Out:
# 📋 DATAFRAME STRUCTURE:
# Index: Depth_ft (shape: (10,))
# Columns: ['Sample_ID', 'XRD_Calcite', 'XRD_Dolomite', 'XRD_Ankerite', 'XRD_Siderite', 'XRD_Quartz', 'XRD_Plagioclase', 'XRD_K-Feldspar', 'XRD_Illite/Mica', 'XRD_Smectite', 'XRD_Kaolinite', 'XRD_Chlorite', 'XRD_Mixed Clay', 'XRD_Anhydrite', 'XRD_Gypsum', 'XRD_Pyrite', 'XRD_Hematite', 'XRF_Na', 'XRF_Mg', 'XRF_Al', 'XRF_Si', 'XRF_P', 'XRF_S', 'XRF_Cl', 'XRF_K', 'XRF_Ca', 'XRF_Ti', 'XRF_Mn', 'XRF_Fe', 'XRF_Zr', 'XRF_Sr', 'XRF_Ba'] (shape: (10, 32))
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 14889.2 to 14938.5
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sample_ID        10 non-null     int64
#  1   XRD_Calcite      10 non-null     int64
#  2   XRD_Dolomite     10 non-null     int64
#  3   XRD_Ankerite     10 non-null     int64
#  4   XRD_Siderite     10 non-null     int64
#  5   XRD_Quartz       10 non-null     float64
#  6   XRD_Plagioclase  10 non-null     int64
#  7   XRD_K-Feldspar   10 non-null     float64
#  8   XRD_Illite/Mica  10 non-null     float64
#  9   XRD_Smectite     10 non-null     int64
#  10  XRD_Kaolinite    10 non-null     int64
#  11  XRD_Chlorite     10 non-null     float64
#  12  XRD_Mixed Clay   10 non-null     int64
#  13  XRD_Anhydrite    10 non-null     int64
#  14  XRD_Gypsum       10 non-null     int64
#  15  XRD_Pyrite       10 non-null     int64
#  16  XRD_Hematite     10 non-null     int64
#  17  XRF_Na           10 non-null     float64
#  18  XRF_Mg           10 non-null     float64
#  19  XRF_Al           10 non-null     float64
#  20  XRF_Si           10 non-null     float64
#  21  XRF_P            10 non-null     float64
#  22  XRF_S            10 non-null     float64
#  23  XRF_Cl           10 non-null     float64
#  24  XRF_K            10 non-null     float64
#  25  XRF_Ca           10 non-null     float64
#  26  XRF_Ti           10 non-null     float64
#  27  XRF_Mn           10 non-null     int64
#  28  XRF_Fe           10 non-null     float64
#  29  XRF_Zr           10 non-null     float64
#  30  XRF_Sr           10 non-null     float64
#  31  XRF_Ba           10 non-null     int64
# dtypes: float64(17), int64(15)
# memory usage: 2.6 KB
# Data types:
# None

# %%
# Extracting XRF and XRD columns
# Assuming the columns start with 'XRF_' or 'XRD_'
# xrf_xrd_columns = [c for c in lab_data.columns if c.startswith(('XRF_', 'XRD_'))]
# lab_df = lab_data[xrf_xrd_columns] 
# lab_df

lab_data
# Out:
#           Sample_ID  XRD_Calcite  XRD_Dolomite  XRD_Ankerite  XRD_Siderite  \
# Depth_ft
# 14889.2           2            0             0             0             0
# 14893.8           3            0             0             0             0
# 14894.7           4            0             0             0             0
# 14895.3           5            0             0             0             0
# 14901.9           6            0             0             0             0
# 14903.7           7            0             0             0             0
# 14905.7           8            0             0             0             0
# 14931.5          14            0             0             0             0
# 14932.4          15            0             0             0             0
# 14938.5          17            0             0             0             0
#
#           XRD_Quartz  XRD_Plagioclase  XRD_K-Feldspar  XRD_Illite/Mica  \
# Depth_ft
# 14889.2         99.2                0             0.0              0.7
# 14893.8         96.1                0             0.0              3.8
# 14894.7         96.5                0             0.0              3.4
# 14895.3         95.1                0             0.0              4.8
# 14901.9         96.7                0             0.9              2.0
# 14903.7         97.4                0             0.0              2.5
# 14905.7         94.0                0             0.0              5.9
# 14931.5         92.0                0             0.0              7.9
# 14932.4         95.0                0             0.0              4.9
# 14938.5         95.0                0             0.0              4.9
#
#           XRD_Smectite  ...  XRF_S  XRF_Cl  XRF_K  XRF_Ca  XRF_Ti  XRF_Mn  \
# Depth_ft                ...
# 14889.2              0  ...   0.11    0.69   2.74    1.19    0.00       0
# 14893.8              0  ...   0.00    1.25   5.30    1.48    0.25       0
# 14894.7              0  ...   0.56    1.01   4.23    3.07    0.37       0
# 14895.3              0  ...   0.11    1.14   6.24    1.19    0.70       0
# 14901.9              0  ...   0.64    1.03   4.05    3.24    0.68       0
# 14903.7              0  ...   0.00    0.96   4.10    0.94    0.65       0
# 14905.7              0  ...   0.00    1.11   7.96    1.34    0.83       0
# 14931.5              0  ...   0.15    1.33   5.96    1.68    0.86       0
# 14932.4              0  ...   0.00    2.05   4.86    1.87    0.44       0
# 14938.5              0  ...   0.33    1.51   8.44    2.99    1.76       0
#
#           XRF_Fe  XRF_Zr  XRF_Sr  XRF_Ba
# Depth_ft
# 14889.2     0.59    0.14    0.00       0
# 14893.8     1.14    0.08    0.00       0
# 14894.7     0.98    0.08    0.00       0
# 14895.3     1.72    0.17    0.00       0
# 14901.9     1.68    0.22    0.00       0
# 14903.7     0.80    0.16    0.00       0
# 14905.7     1.63    0.00    0.04       0
# 14931.5     1.76    0.14    0.00       0
# 14932.4     1.48    0.10    0.00       0
# 14938.5     3.52    0.10    0.24       0
#
# [10 rows x 32 columns]

# %% [markdown]
# # extracting log dlis

# %%
def dlis_to_df(path, needed=None):
    """Load DLIS file and return a DataFrame with well log data."""
    log = dlis.load(path)[0]
    frame = log.frames[0]
    
    # Get channel names for reference
    channel_names = [ch.name for ch in frame.channels]
    print(f"Found {len(channel_names)} channels: {channel_names[:]}...")
    
    try:
        # Get the curves data as a structured array
        curves_data = frame.curves()
        print(f"Curves data type: {type(curves_data)}")
        
        # Check if it's a structured array with field names
        if hasattr(curves_data.dtype, 'names') and curves_data.dtype.names:
            field_names = curves_data.dtype.names
            print(f"Found structured array with {len(field_names)} fields")
            
            # Create a dictionary to map field names to simple channel names
            field_to_channel = {}
            for field in field_names:
                # For complex field names like (('T.CHANNEL-I.GR-O.1-C.0', 'GR'), '<f4')
                try:
                    if isinstance(field, tuple) and len(field) > 1:
                        if isinstance(field[0], tuple):
                            simple_name = field[0][1]  # Extract 'GR' from the tuple
                            field_to_channel[field] = simple_name
                        continue
                except:
                    pass
                
                # For simpler string field names
                for name in channel_names:
                    if name in str(field):
                        field_to_channel[field] = name
                        break
            
            # Extract data for each field - handle multi-dimensional arrays
            data_dict = {}
            for field in field_names:
                # Get the simple name if we mapped it
                simple_name = field_to_channel.get(field)
                if not simple_name:
                    continue
                
                try:
                    # Get the data
                    array = curves_data[field]
                    
                    # Check if it's multi-dimensional
                    if array.ndim > 1 or (hasattr(array, 'shape') and len(array.shape) > 1):
                        # For multi-dimensional arrays, take first element or flatten
                        print(f"Skipping multi-dimensional array for {simple_name} with shape {array.shape}")
                        continue
                    
                    # Only add 1D arrays to our dictionary
                    data_dict[simple_name] = array
                    
                except Exception as e:
                    print(f"Error extracting {simple_name} from {field}: {e}")
            
            # Find the depth channel
            depth_channel = 'TDEP'
            if depth_channel not in data_dict:
                for name in ['DEPTH', 'DEPT', 'Depth', 'depth']:
                    if name in data_dict:
                        depth_channel = name
                        break
            
            # Create DataFrame
            if data_dict:
                # Make sure all arrays have the same length
                lengths = {name: len(arr) for name, arr in data_dict.items()}
                if len(set(lengths.values())) > 1:
                    print(f"Warning: Arrays have different lengths: {lengths}")
                    # Find minimum length and truncate all arrays
                    min_len = min(lengths.values())
                    data_dict = {name: arr[:min_len] for name, arr in data_dict.items()}
                
                df = pd.DataFrame(data_dict)
                
                # Set depth as index if it exists
                if depth_channel in df.columns:
                    df = df.set_index(depth_channel)
                
                # Filter columns if needed
                if needed is not None:
                    valid_cols = [col for col in needed if col in df.columns]
                    if valid_cols:
                        df = df[valid_cols]
                    else:
                        print(f"Warning: None of the requested columns found in {list(df.columns)}")
                
                print(f"Final DataFrame shape: {df.shape}")
                return df
            else:
                print("Could not extract any data from fields")
                return pd.DataFrame()
        else:
            print("Curves data is not a structured array with named fields")
            # Print more info about the array to help debugging
            print(f"Array shape: {curves_data.shape}")
            print(f"Array dtype: {curves_data.dtype}")
            print(f"First few values: {curves_data[:5]}")
            return pd.DataFrame()
            
    except Exception as e:
        print(f"Error processing DLIS file: {e}")
        import traceback
        traceback.print_exc()
        return pd.DataFrame()

# Path to the DLIS log file for HRDH-1119
LOG_PATH = r"\\bhidhares01\GROUPS\Daleelah_Interns\2025 interns\Ziyad alghamdi\transtion_minerals\Log Data\HRDH_697_0\8375\WL\Field\Top_Section\Field\FJA\GSLAM\HRDH_697_0_27OCT2011_ZDL-CNC-DSL-GR-CAL_ML_BA.dlis"


# Load log data 
log_df = dlis_to_df(LOG_PATH)
log_df
# Out:
# Found 35 channels: ['TDEP', 'BIT', 'BVOL', 'CALZ', 'CN', 'CNC', 'CVOL', 'GR', 'GRSL', 'HRD1', 'HRD2', 'K', 'KTH', 'LSN', 'PE', 'QPKS', 'RTHK', 'RTHU', 'RUK', 'SFT2', 'SHR', 'SLGN', 'SLSP', 'SLSPQ0', 'SLTM', 'SPD', 'SSD', 'SSN', 'TEN', 'TH', 'TTEN', 'U', 'ZCOR', 'ZDEN', 'ZDNC']...
# Curves data type: <class 'numpy.ndarray'>
# Found structured array with 36 fields
# Skipping multi-dimensional array for SLSP with shape (947, 254)
# Skipping multi-dimensional array for SLSP with shape (947, 254)
# Final DataFrame shape: (947, 25)
#             BIT        BVOL        CALZ          CN        CVOL          GR  \
# TDEP
# 14516.00  8.375   99.497322    9.532839   43.618660   37.837200   37.221199
# 14516.25  8.375   99.373413    9.501544   42.318863   37.780102   38.086845
# 14516.50  8.375   99.250313    9.460791   39.761799   37.723816   38.507370
# 14516.75  8.375   99.128265    9.426017   36.318920   37.668583   38.153141
# 14517.00  8.375   99.007118    9.407530   32.642059   37.614246   36.868286
# ...         ...         ...         ...         ...         ...         ...
# 14751.50  8.375 -999.250000 -999.250000 -999.250000 -999.250000 -999.250000
# 14751.75  8.375 -999.250000 -999.250000 -999.250000 -999.250000 -999.250000
# 14752.00  8.375 -999.250000 -999.250000 -999.250000 -999.250000 -999.250000
# 14752.25  8.375 -999.250000 -999.250000 -999.250000 -999.250000 -999.250000
# 14752.50  8.375 -999.250000 -999.250000 -999.250000 -999.250000 -999.250000
#
#                  HRD1         HRD2           K         LSN  ...    SLTM  \
# TDEP                                                        ...
# 14516.00  1531.134155  2436.565430    6.118960  373.862640  ...  828.00
# 14516.25  1529.901001  2446.000977    6.183754  399.692902  ...  822.00
# 14516.50  1504.856689  2415.580811    6.219876  436.135193  ...  827.00
# 14516.75  1456.647339  2340.736572    6.318686  484.094727  ...  817.00
# 14517.00  1382.685181  2214.714355    6.735315  542.124207  ...  838.00
# ...               ...          ...         ...         ...  ...     ...
# 14751.50  -999.250000  -999.250000 -999.250000 -999.250000  ... -999.25
# 14751.75  -999.250000  -999.250000 -999.250000 -999.250000  ... -999.25
# 14752.00  -999.250000  -999.250000 -999.250000 -999.250000  ... -999.25
# 14752.25  -999.250000  -999.250000 -999.250000 -999.250000  ... -999.25
# 14752.50  -999.250000  -999.250000 -999.250000 -999.250000  ... -999.25
#
#                  SPD           SSD          SSN          TEN          TH  \
# TDEP
# 14516.00   18.618334  23409.593750  1444.882324  7040.770020    3.304434
# 14516.25   18.633112  23060.994141  1525.919189  7039.204102    3.115459
# 14516.50   18.648123  23049.742188  1622.432251  7037.895996    2.971437
# 14516.75   18.660591  23379.875000  1731.027344  7036.349609    2.857349
# 14517.00   18.667870  23852.794922  1845.465332  7034.042969    2.723381
# ...              ...           ...          ...          ...         ...
# 14751.50 -999.250000   -999.250000  -999.250000  -999.250000 -999.250000
# 14751.75 -999.250000   -999.250000  -999.250000  -999.250000 -999.250000
# 14752.00 -999.250000   -999.250000  -999.250000  -999.250000 -999.250000
# 14752.25 -999.250000   -999.250000  -999.250000  -999.250000 -999.250000
# 14752.50 -999.250000   -999.250000  -999.250000  -999.250000 -999.250000
#
#                    U        ZCOR        ZDEN        ZDNC
# TDEP
# 14516.00    3.012343   -0.089123    2.114847    2.108802
# 14516.25    2.973576   -0.085361    2.117693    2.111642
# 14516.50    2.943866   -0.081531    2.127755    2.121636
# 14516.75    2.937430   -0.075375    2.148059    2.141778
# 14517.00    2.981162   -0.065684    2.181750    2.175191
# ...              ...         ...         ...         ...
# 14751.50 -999.250000 -999.250000 -999.250000 -999.250000
# 14751.75 -999.250000 -999.250000 -999.250000 -999.250000
# 14752.00 -999.250000 -999.250000 -999.250000 -999.250000
# 14752.25 -999.250000 -999.250000 -999.250000 -999.250000
# 14752.50 -999.250000 -999.250000 -999.250000 -999.250000
#
# [947 rows x 25 columns]

# %% [markdown]
# # cleaning log

# %%
# no missing values in lab_df since all -999.25 values are not consinderd as null
null_values = -999.25

# Replace -999.25 with NaN FIRST
log_df_clean = log_df.replace(null_values, np.nan)
log_df_clean
# Out:
#             BIT       BVOL      CALZ         CN       CVOL         GR  \
# TDEP
# 14516.00  8.375  99.497322  9.532839  43.618660  37.837200  37.221199
# 14516.25  8.375  99.373413  9.501544  42.318863  37.780102  38.086845
# 14516.50  8.375  99.250313  9.460791  39.761799  37.723816  38.507370
# 14516.75  8.375  99.128265  9.426017  36.318920  37.668583  38.153141
# 14517.00  8.375  99.007118  9.407530  32.642059  37.614246  36.868286
# ...         ...        ...       ...        ...        ...        ...
# 14751.50  8.375        NaN       NaN        NaN        NaN        NaN
# 14751.75  8.375        NaN       NaN        NaN        NaN        NaN
# 14752.00  8.375        NaN       NaN        NaN        NaN        NaN
# 14752.25  8.375        NaN       NaN        NaN        NaN        NaN
# 14752.50  8.375        NaN       NaN        NaN        NaN        NaN
#
#                  HRD1         HRD2         K         LSN  ...   SLTM  \
# TDEP                                                      ...
# 14516.00  1531.134155  2436.565430  6.118960  373.862640  ...  828.0
# 14516.25  1529.901001  2446.000977  6.183754  399.692902  ...  822.0
# 14516.50  1504.856689  2415.580811  6.219876  436.135193  ...  827.0
# 14516.75  1456.647339  2340.736572  6.318686  484.094727  ...  817.0
# 14517.00  1382.685181  2214.714355  6.735315  542.124207  ...  838.0
# ...               ...          ...       ...         ...  ...    ...
# 14751.50          NaN          NaN       NaN         NaN  ...    NaN
# 14751.75          NaN          NaN       NaN         NaN  ...    NaN
# 14752.00          NaN          NaN       NaN         NaN  ...    NaN
# 14752.25          NaN          NaN       NaN         NaN  ...    NaN
# 14752.50          NaN          NaN       NaN         NaN  ...    NaN
#
#                 SPD           SSD          SSN          TEN        TH  \
# TDEP
# 14516.00  18.618334  23409.593750  1444.882324  7040.770020  3.304434
# 14516.25  18.633112  23060.994141  1525.919189  7039.204102  3.115459
# 14516.50  18.648123  23049.742188  1622.432251  7037.895996  2.971437
# 14516.75  18.660591  23379.875000  1731.027344  7036.349609  2.857349
# 14517.00  18.667870  23852.794922  1845.465332  7034.042969  2.723381
# ...             ...           ...          ...          ...       ...
# 14751.50        NaN           NaN          NaN          NaN       NaN
# 14751.75        NaN           NaN          NaN          NaN       NaN
# 14752.00        NaN           NaN          NaN          NaN       NaN
# 14752.25        NaN           NaN          NaN          NaN       NaN
# 14752.50        NaN           NaN          NaN          NaN       NaN
#
#                  U      ZCOR      ZDEN      ZDNC
# TDEP
# 14516.00  3.012343 -0.089123  2.114847  2.108802
# 14516.25  2.973576 -0.085361  2.117693  2.111642
# 14516.50  2.943866 -0.081531  2.127755  2.121636
# 14516.75  2.937430 -0.075375  2.148059  2.141778
# 14517.00  2.981162 -0.065684  2.181750  2.175191
# ...            ...       ...       ...       ...
# 14751.50       NaN       NaN       NaN       NaN
# 14751.75       NaN       NaN       NaN       NaN
# 14752.00       NaN       NaN       NaN       NaN
# 14752.25       NaN       NaN       NaN       NaN
# 14752.50       NaN       NaN       NaN       NaN
#
# [947 rows x 25 columns]

# %% [markdown]
# # MISSING DATA SUMMARY

# %%
# THEN calculate missingness summary
null_pct = log_df_clean.isna().mean() * 100
print("🔍 MISSING DATA SUMMARY:")
print("=" * 50)

# More readable format for many columns
if len(null_pct) > 10:
    # Show only columns with missing data
    missing_cols = null_pct[null_pct > 0].sort_values(ascending=False)
    if len(missing_cols) > 0:
        print(f"📊 Columns with missing data ({len(missing_cols)}/{len(null_pct)}):")
        for col, pct in missing_cols.items():
            print(f"   • {col:<20}: {pct:>6.1f}%")
    else:
        print("✅ No missing data found!")
    
    # Summary stats
    print(f"\n📈 SUMMARY:")
    print(f"   • Total columns: {len(null_pct)}")
    print(f"   • Columns with missing data: {len(missing_cols)}")
    print(f"   • Max missing %: {null_pct.max():.1f}%")
    print(f"   • Avg missing %: {null_pct.mean():.1f}%")
else:
    # Original format for few columns
    print(null_pct.sort_values(ascending=False))

# Post-QA check
remaining_nulls = log_df_clean.isna().sum().sort_values(ascending=False)
remaining_nulls_filtered = remaining_nulls[remaining_nulls > 0]

print(f"\n✅ POST-PROCESSING CHECK:")
if remaining_nulls_filtered.empty:
    print("   No nulls remain!")
else:
    print(f"   Columns with nulls: {len(remaining_nulls_filtered)}")
    if len(remaining_nulls_filtered) <= 5:
        print(remaining_nulls_filtered)
    else:
        print("   Top 5 columns with most nulls:")
        print(remaining_nulls_filtered.head())

# Final dataset ready
print(f"\n🎯 DATASET READY: {log_df_clean.shape[0]} samples × {log_df_clean.shape[1]} curves")
log_df_clean
# Out:
# 🔍 MISSING DATA SUMMARY:
# ==================================================
# 📊 Columns with missing data (24/25):
#    • K                   :   40.5%
#    • U                   :   40.5%
#    • TH                  :   40.5%
#    • RTHU                :   40.5%
#    • GR                  :   39.7%
#    • SLGN                :   39.2%
#    • SLTM                :   39.1%
#    • CN                  :   37.1%
#    • LSN                 :   37.1%
#    • SSN                 :   37.1%
#    • PE                  :   32.8%
#    • ZDEN                :   32.7%
#    • ZCOR                :   32.7%
#    • ZDNC                :   32.7%
#    • HRD1                :   32.6%
#    • HRD2                :   32.6%
#    • SHR                 :   32.6%
#    • SFT2                :   32.6%
#    • CALZ                :   32.2%
#    • SSD                 :   31.9%
#    • BVOL                :    2.5%
#    • CVOL                :    2.5%
#    • SPD                 :    0.6%
#    • TEN                 :    0.5%
#
# 📈 SUMMARY:
#    • Total columns: 25
#    • Columns with missing data: 24
#    • Max missing %: 40.5%
#    • Avg missing %: 28.9%
#
# ✅ POST-PROCESSING CHECK:
#    Columns with nulls: 24
#    Top 5 columns with most nulls:
# K       384
# TH      384
# U       384
# RTHU    384
# GR      376
# dtype: int64
#
# 🎯 DATASET READY: 947 samples × 25 curves
#             BIT       BVOL      CALZ         CN       CVOL         GR  \
# TDEP
# 14516.00  8.375  99.497322  9.532839  43.618660  37.837200  37.221199
# 14516.25  8.375  99.373413  9.501544  42.318863  37.780102  38.086845
# 14516.50  8.375  99.250313  9.460791  39.761799  37.723816  38.507370
# 14516.75  8.375  99.128265  9.426017  36.318920  37.668583  38.153141
# 14517.00  8.375  99.007118  9.407530  32.642059  37.614246  36.868286
# ...         ...        ...       ...        ...        ...        ...
# 14751.50  8.375        NaN       NaN        NaN        NaN        NaN
# 14751.75  8.375        NaN       NaN        NaN        NaN        NaN
# 14752.00  8.375        NaN       NaN        NaN        NaN        NaN
# 14752.25  8.375        NaN       NaN        NaN        NaN        NaN
# 14752.50  8.375        NaN       NaN        NaN        NaN        NaN
#
#                  HRD1         HRD2         K         LSN  ...   SLTM  \
# TDEP                                                      ...
# 14516.00  1531.134155  2436.565430  6.118960  373.862640  ...  828.0
# 14516.25  1529.901001  2446.000977  6.183754  399.692902  ...  822.0
# 14516.50  1504.856689  2415.580811  6.219876  436.135193  ...  827.0
# 14516.75  1456.647339  2340.736572  6.318686  484.094727  ...  817.0
# 14517.00  1382.685181  2214.714355  6.735315  542.124207  ...  838.0
# ...               ...          ...       ...         ...  ...    ...
# 14751.50          NaN          NaN       NaN         NaN  ...    NaN
# 14751.75          NaN          NaN       NaN         NaN  ...    NaN
# 14752.00          NaN          NaN       NaN         NaN  ...    NaN
# 14752.25          NaN          NaN       NaN         NaN  ...    NaN
# 14752.50          NaN          NaN       NaN         NaN  ...    NaN
#
#                 SPD           SSD          SSN          TEN        TH  \
# TDEP
# 14516.00  18.618334  23409.593750  1444.882324  7040.770020  3.304434
# 14516.25  18.633112  23060.994141  1525.919189  7039.204102  3.115459
# 14516.50  18.648123  23049.742188  1622.432251  7037.895996  2.971437
# 14516.75  18.660591  23379.875000  1731.027344  7036.349609  2.857349
# 14517.00  18.667870  23852.794922  1845.465332  7034.042969  2.723381
# ...             ...           ...          ...          ...       ...
# 14751.50        NaN           NaN          NaN          NaN       NaN
# 14751.75        NaN           NaN          NaN          NaN       NaN
# 14752.00        NaN           NaN          NaN          NaN       NaN
# 14752.25        NaN           NaN          NaN          NaN       NaN
# 14752.50        NaN           NaN          NaN          NaN       NaN
#
#                  U      ZCOR      ZDEN      ZDNC
# TDEP
# 14516.00  3.012343 -0.089123  2.114847  2.108802
# 14516.25  2.973576 -0.085361  2.117693  2.111642
# 14516.50  2.943866 -0.081531  2.127755  2.121636
# 14516.75  2.937430 -0.075375  2.148059  2.141778
# 14517.00  2.981162 -0.065684  2.181750  2.175191
# ...            ...       ...       ...       ...
# 14751.50       NaN       NaN       NaN       NaN
# 14751.75       NaN       NaN       NaN       NaN
# 14752.00       NaN       NaN       NaN       NaN
# 14752.25       NaN       NaN       NaN       NaN
# 14752.50       NaN       NaN       NaN       NaN
#
# [947 rows x 25 columns]

# %%
# Display first few depth values from both datasets
# print("First 10 log depths:")
# print(log_df.index[:10])

# print("\nFirst 10 lab depths:")
# print(lab_data.index[:10])

# Create a DataFrame to summarize both depth distributions
depth_stats = pd.DataFrame({
    'Log Depths': pd.Series(log_df_clean.index),
    'Lab Depths': pd.Series(lab_data.index),
})
#  Display summary statistics
print("\nDepth statistics:")
print(depth_stats.describe())

#Summary of the number of nulls
print("Statistics Summary of log_df cleaning")
log_df_clean.describe()

# Quick check for duplicates
print("\n🔍 DUPLICATE DEPTH CHECK:")
print(f"Log duplicates: {log_df_clean.index.duplicated().sum()}")
print(f"Lab duplicates: {lab_data.index.duplicated().sum()}")

# Show unique vs total counts
print(f"\nLog depths - Total: {len(log_df_clean)}, Unique: {log_df_clean.index.nunique()}")
print(f"Lab depths - Total: {len(lab_data)}, Unique: {lab_data.index.nunique()}")
# Out:
# Depth statistics:
#          Log Depths    Lab Depths
# count    947.000000     10.000000
# mean   14634.250000  14908.670000
# std       68.379913     18.341274
# min    14516.000000  14889.200000
# 25%    14575.125000  14894.850000
# 50%    14634.250000  14902.800000
# 75%    14693.375000  14925.050000
# max    14752.500000  14938.500000
# Statistics Summary of log_df cleaning
#
# 🔍 DUPLICATE DEPTH CHECK:
# Log duplicates: 0
# Lab duplicates: 0
#
# Log depths - Total: 947, Unique: 947
# Lab depths - Total: 10, Unique: 10

# %%
# Add this diagnostic cell to clearly show the gap
print("🔍 DEPTH RANGE DIAGNOSTIC:")
print("=" * 50)

log_min, log_max = log_df_clean.index.min(), log_df_clean.index.max()
lab_min, lab_max = lab_data.index.min(), lab_data.index.max()

print(f"📊 DEPTH RANGES:")
print(f"   • Log data: {log_min:.1f} - {log_max:.1f} ft ({log_max - log_min:.1f} ft span)")
print(f"   • Lab data: {lab_min:.1f} - {lab_max:.1f} ft ({lab_max - lab_min:.1f} ft span)")

# Calculate the gap
gap = lab_min - log_max
print(f"\n❌ DEPTH GAP DETECTED:")
print(f"   • Gap size: {gap:.1f} ft")
print(f"   • Log ends at: {log_max:.1f} ft")
print(f"   • Lab starts at: {lab_min:.1f} ft")
print(f"   • This explains why you have 0 matches!")


# Test depth shift
print(f"\n🧪 TEST: IF WE SHIFT LAB DATA BY -{gap:.1f} ft:")
shifted_lab_min = lab_min - gap
shifted_lab_max = lab_max - gap
print(f"   • Shifted lab range: {shifted_lab_min:.1f} - {shifted_lab_max:.1f} ft")

# Check overlap after shift
overlap_start_shifted = max(log_min, shifted_lab_min)
overlap_end_shifted = min(log_max, shifted_lab_max)
overlap_span_shifted = overlap_end_shifted - overlap_start_shifted

if overlap_span_shifted > 0:
    print(f"   ✅ Would create {overlap_span_shifted:.1f} ft overlap!")
    print(f"   • Overlap zone: {overlap_start_shifted:.1f} - {overlap_end_shifted:.1f} ft")
else:
    print(f"   ❌ Still no overlap after shift")
# Out:
# 🔍 DEPTH RANGE DIAGNOSTIC:
# ==================================================
# 📊 DEPTH RANGES:
#    • Log data: 14516.0 - 14752.5 ft (236.5 ft span)
#    • Lab data: 14889.2 - 14938.5 ft (49.3 ft span)
#
# ❌ DEPTH GAP DETECTED:
#    • Gap size: 136.7 ft
#    • Log ends at: 14752.5 ft
#    • Lab starts at: 14889.2 ft
#    • This explains why you have 0 matches!
#
# 🧪 TEST: IF WE SHIFT LAB DATA BY -136.7 ft:
#    • Shifted lab range: 14752.5 - 14801.8 ft
#    ❌ Still no overlap after shift

# %%
# Let's analyze the overlap zone more clearly
print("🔍 DETAILED OVERLAP ZONE ANALYSIS:")
print("=" * 50)

overlap_start = max(lab_data.index.min(), log_df_clean.index.min())
overlap_end = min(lab_data.index.max(), log_df_clean.index.max())

print(f"📊 OVERLAP ZONE: {overlap_start:.1f} - {overlap_end:.1f} ft")
print(f"   • Zone span: {overlap_end - overlap_start:.1f} ft")

# Get samples in overlap zone
log_overlap = log_df_clean[(log_df_clean.index >= overlap_start) & (log_df_clean.index <= overlap_end)]
lab_overlap = lab_data[(lab_data.index >= overlap_start) & (lab_data.index <= overlap_end)]

print(f"\n📈 SAMPLING DENSITY IN OVERLAP:")
print(f"   • Log samples: {len(log_overlap)} samples")
print(f"   • Lab samples: {len(lab_overlap)} samples")
# print(f"   • Ratio: {len(log_overlap)/len(lab_overlap):.1f} log samples per lab sample")

# Show the actual depths
print(f"\n📍 ACTUAL DEPTHS IN OVERLAP ZONE:")
print(f"🔵 Log depths (first 10 of {len(log_overlap)}):")
for i, depth in enumerate(log_overlap.index[:10]):
    print(f"   {i+1:2d}. {depth:.2f} ft")

print(f"\n🔴 Lab depths (all {len(lab_overlap)}):")
for i, depth in enumerate(lab_overlap.index):
    print(f"   {i+1:2d}. {depth:.1f} ft")

# Calculate spacing
log_spacing_overlap = np.diff(log_overlap.index)
lab_spacing_overlap = np.diff(lab_overlap.index)

print(f"\n📏 SPACING ANALYSIS IN OVERLAP:")
print(f"   • Log spacing: {log_spacing_overlap.mean():.2f} ft average")
print(f"   • Lab spacing: {lab_spacing_overlap.mean():.2f} ft average")
print(f"   • Lab samples are ~{lab_spacing_overlap.mean()/log_spacing_overlap.mean():.0f}x further apart")

# This explains why you get 96 vs 3
print(f"\n💡 EXPLANATION:")
print(f"   • Log data: High resolution (every ~{log_spacing_overlap.mean():.2f} ft)")
print(f"   • Lab data: Sparse sampling (every ~{lab_spacing_overlap.mean():.1f} ft)")
print(f"   • In a {overlap_end - overlap_start:.1f} ft zone:")
print(f"     - Log: {len(log_overlap)} samples (high resolution)")
print(f"     - Lab: {len(lab_overlap)} samples (sparse)")
# Out:
# 🔍 DETAILED OVERLAP ZONE ANALYSIS:
# ==================================================
# 📊 OVERLAP ZONE: 14889.2 - 14752.5 ft
#    • Zone span: -136.7 ft
#
# 📈 SAMPLING DENSITY IN OVERLAP:
#    • Log samples: 0 samples
#    • Lab samples: 0 samples
#
# 📍 ACTUAL DEPTHS IN OVERLAP ZONE:
# 🔵 Log depths (first 10 of 0):
#
# 🔴 Lab depths (all 0):
#
# 📏 SPACING ANALYSIS IN OVERLAP:
#    • Log spacing: nan ft average
#    • Lab spacing: nan ft average
#    • Lab samples are ~nanx further apart
#
# 💡 EXPLANATION:
#    • Log data: High resolution (every ~nan ft)
#    • Lab data: Sparse sampling (every ~nan ft)
#    • In a -136.7 ft zone:
#      - Log: 0 samples (high resolution)
#      - Lab: 0 samples (sparse)
# C:\Users\alghziy\AppData\Local\Temp\ipykernel_20464\679557695.py:35: RuntimeWarning: Mean of empty slice.
#   print(f"   • Log spacing: {log_spacing_overlap.mean():.2f} ft average")
# C:\Users\alghziy\AppData\Local\Temp\ipykernel_20464\679557695.py:36: RuntimeWarning: Mean of empty slice.
#   print(f"   • Lab spacing: {lab_spacing_overlap.mean():.2f} ft average")
# C:\Users\alghziy\AppData\Local\Temp\ipykernel_20464\679557695.py:37: RuntimeWarning: Mean of empty slice.
#   print(f"   • Lab samples are ~{lab_spacing_overlap.mean()/log_spacing_overlap.mean():.0f}x further apart")
# C:\Users\alghziy\AppData\Local\Temp\ipykernel_20464\679557695.py:41: RuntimeWarning: Mean of empty slice.
#   print(f"   • Log data: High resolution (every ~{log_spacing_overlap.mean():.2f} ft)")
# C:\Users\alghziy\AppData\Local\Temp\ipykernel_20464\679557695.py:42: RuntimeWarning: Mean of empty slice.
#   print(f"   • Lab data: Sparse sampling (every ~{lab_spacing_overlap.mean():.1f} ft)")

# %% [markdown]
# # join

# %%
from scipy.spatial import cKDTree
import numpy as np
import pandas as pd
tolerance_ft = 0.5

def match_lab_to_log(log_df, lab_df, tol=0.5):
    """
    For each lab depth, find the nearest log depth within `tol`.
    Returns at most len(lab_df) matched pairs.
    Adds columns for Distance and Match_Type.
    """
    # Ensure unique indices
    log = log_df[~log_df.index.duplicated(keep='first')]
    lab = lab_df[~lab_df.index.duplicated(keep='first')]
    
    # Build KD-Tree on log depths
    log_depths = log.index.values.reshape(-1,1)
    tree = cKDTree(log_depths)
    
    # Query each lab depth
    lab_depths = lab.index.values.reshape(-1,1)
    dists, idxs = tree.query(lab_depths, distance_upper_bound=tol)
    
    # Keep only lab samples that found a log partner
    mask = ~np.isinf(dists)
    matched_lab = lab.iloc[mask].reset_index()
    matched_log = log.iloc[idxs[mask]].reset_index()

    # Rename depth columns explicitly
    matched_lab = matched_lab.rename(columns={matched_lab.columns[0]: 'Lab_Depth'})
    matched_log = matched_log.rename(columns={matched_log.columns[0]: 'Log_Depth'})

    # Concatenate side-by-side: one row per lab sample (keep Log_Depth)
    joined = pd.concat([matched_lab, matched_log], axis=1)
    # Add distance column
    joined['Distance'] = np.abs(joined['Lab_Depth'] - joined['Log_Depth'])
    # Add match type column
    joined['Match_Type'] = np.where(joined['Distance'] == 0, 'Exact', 'Near')
    return joined

# Usage example:
# log_df_clean = your QA’d log DataFrame (depth index)
# lab_df = your lab assay DataFrame (depth index)
joined_df_lab = match_lab_to_log(log_df_clean, lab_data, tol=1.0)

print(f"Lab samples: {len(lab_data)} → Matched pairs: {len(joined_df_lab)}")


# Use the new function
joined_df = match_lab_to_log(log_df_clean, lab_data, tolerance_ft)

print(f"\n✅ FINAL RESULTS:")
print(f"   • Found {len(joined_df)} matches with {tolerance_ft} ft tolerance")
print(f"   • Lab samples: {len(lab_data)}")
print(f"   • This is ≤ {len(lab_data)} ✓")

# Show match summary
if len(joined_df) > 0:
    match_summary = joined_df['Match_Type'].value_counts()
    print(f"\n📊 MATCH BREAKDOWN:")
    for match_type, count in match_summary.items():
        print(f"   • {match_type.title()} matches: {count}")
    
    print(f"\n🎯 DEPTH ACCURACY:")
    print(f"   • Average distance: {joined_df['Distance'].mean():.2f} ft")
    print(f"   • Max distance: {joined_df['Distance'].max():.2f} ft")
    print(f"   • Min distance: {joined_df['Distance'].min():.2f} ft")

joined_df
# Out:
# Lab samples: 18 → Matched pairs: 3
#
# ✅ FINAL RESULTS:
#    • Found 3 matches with 0.5 ft tolerance
#    • Lab samples: 18
#    • This is ≤ 18 ✓
#
# 📊 MATCH BREAKDOWN:
#    • Exact matches: 2
#    • Near matches: 1
#
# 🎯 DEPTH ACCURACY:
#    • Average distance: 0.03 ft
#    • Max distance: 0.10 ft
#    • Min distance: 0.00 ft
#    Lab_Depth  Sample_ID  XRD_Calcite  XRD_Dolomite  XRD_Ankerite  \
# 0    10864.5        124         36.1          61.7             0
# 1    10865.4        125         40.9          50.9             0
# 2    10866.5        126         39.8          47.1             0
#
#    XRD_Siderite  XRD_Quartz  XRD_Plagioclase  XRD_K-Feldspar  XRD_Illite/Mica  \
# 0             0         0.1              0.4               0                0
# 1             0         0.2              0.3               0                0
# 2             0         0.1              0.3               0                0
#
#    ...          SSN  TEN        TH         U        WTBH  ZCOR  ZDEN  ZDNC  \
# 0  ...  1750.766357  NaN  0.478374  0.555232  227.370560   NaN   NaN   NaN
# 1  ...  1762.270508  NaN  0.350824  0.532203  227.209198   NaN   NaN   NaN
# 2  ...  1786.388428  NaN  0.515622  0.248103  226.876907   NaN   NaN   NaN
#
#    Distance  Match_Type
# 0       0.0       Exact
# 1       0.1        Near
# 2       0.0       Exact
#
# [3 rows x 63 columns]

# %%
# Show lab and log depths side by side - CORRECTED VERSION
print("📊 DEPTH COMPARISON SUMMARY:")
print("=" * 50)

# Show basic stats first - FIXED: Use correct data sources
print(f"Joined pairs: {len(joined_df)} samples")
print(f"Log depths: {len(log_df_clean)} samples") 
print(f"Lab depths: {len(lab_data)} samples")
print(f"Log range: {log_df_clean.index.min():.1f} - {log_df_clean.index.max():.1f} ft")  # FIXED
print(f"Lab range: {lab_data.index.min():.1f} - {lab_data.index.max():.1f} ft")

# Create side-by-side comparison for overlapping ranges
print(f"\n📋 DEPTH SAMPLES SIDE BY SIDE:")
print("-" * 60)

# Method 2: Show overlap zone analysis - FIXED: Use correct data sources
overlap_start = max(lab_data.index.min(), log_df_clean.index.min())  # FIXED
overlap_end = min(lab_data.index.max(), log_df_clean.index.max())    # FIXED

print(f"\n🔄 OVERLAP ZONE ANALYSIS:")
print(f"Overlap zone: {overlap_start:.1f} - {overlap_end:.1f} ft")

# Get samples in overlap zone - FIXED: Use correct data sources
log_overlap = log_df_clean[(log_df_clean.index >= overlap_start) & (log_df_clean.index <= overlap_end)]  # FIXED
lab_overlap = lab_data[(lab_data.index >= overlap_start) & (lab_data.index <= overlap_end)]

print(f"Log samples in overlap: {len(log_overlap)}")
print(f"Lab samples in overlap: {len(lab_overlap)}")

# Show first few samples from each in overlap zone
print(f"\n📍 FIRST 10 SAMPLES IN OVERLAP ZONE:")
overlap_comparison = pd.DataFrame({
    'Log_Depths_Overlap': pd.Series(log_overlap.index[:10]),
    'Lab_Depths_Overlap': pd.Series(lab_overlap.index[:10])
})
print(overlap_comparison)

# Method 3: Show depth spacing analysis
print(f"\n📏 DEPTH SPACING ANALYSIS:")
log_spacing = np.diff(log_df_clean.index)
lab_spacing = np.diff(lab_data.index)

spacing_stats = pd.DataFrame({
    'Log_Spacing': [log_spacing.mean(), log_spacing.std(), log_spacing.min(), log_spacing.max()],
    'Lab_Spacing': [lab_spacing.mean(), lab_spacing.std(), lab_spacing.min(), lab_spacing.max()]
}, index=['Mean', 'Std', 'Min', 'Max'])

print(spacing_stats)

# BONUS: Show the actual matched pairs clearly
print(f"\n📊 ACTUAL MATCHED PAIRS:")
if len(joined_df) > 0:
    print("Lab_Depth → Log_Depth (Distance)")
    for i, row in joined_df.iterrows():
        print(f"   {row['Lab_Depth']:.1f} ft → {row['Log_Depth']:.2f} ft ({row['Distance']:.2f} ft)")

# Additional analysis: Show why so few matches
print(f"\n🔍 WHY SO FEW MATCHES?")
print(f"   • Log data covers: {log_df_clean.index.min():.1f} to {log_df_clean.index.max():.1f} ft")
print(f"   • Lab data covers: {lab_data.index.min():.1f} to {lab_data.index.max():.1f} ft")
print(f"   • Overlap zone: {overlap_start:.1f} to {overlap_end:.1f} ft ({overlap_end - overlap_start:.1f} ft)")
print(f"   • Tolerance used: {tolerance_ft} ft")
print(f"   • With 0.5 ft tolerance, only {len(joined_df)} lab samples found matches")

# Suggestion for better matching
print(f"\n💡 SUGGESTIONS:")
print(f"   • Try larger tolerance: 1.0-2.0 ft")
print(f"   • Check if depth references match (MD vs TVD)")
print(f"   • Verify both datasets use same depth datum")
# Out:
# 📊 DEPTH COMPARISON SUMMARY:
# ==================================================
# Joined pairs: 3 samples
# Log depths: 2952 samples
# Lab depths: 18 samples
# Log range: 10842.8 - 11580.5 ft
# Lab range: 10742.5 - 10866.5 ft
#
# 📋 DEPTH SAMPLES SIDE BY SIDE:
# ------------------------------------------------------------
#
# 🔄 OVERLAP ZONE ANALYSIS:
# Overlap zone: 10842.8 - 10866.5 ft
# Log samples in overlap: 96
# Lab samples in overlap: 3
#
# 📍 FIRST 10 SAMPLES IN OVERLAP ZONE:
#    Log_Depths_Overlap  Lab_Depths_Overlap
# 0            10842.75             10864.5
# 1            10843.00             10865.4
# 2            10843.25             10866.5
# 3            10843.50                 NaN
# 4            10843.75                 NaN
# 5            10844.00                 NaN
# 6            10844.25                 NaN
# 7            10844.50                 NaN
# 8            10844.75                 NaN
# 9            10845.00                 NaN
#
# 📏 DEPTH SPACING ANALYSIS:
#       Log_Spacing  Lab_Spacing
# Mean         0.25     7.294118
# Std          0.00    14.839315
# Min          0.25     0.900000
# Max          0.25    62.700000
#
# 📊 ACTUAL MATCHED PAIRS:
# Lab_Depth → Log_Depth (Distance)
#    10864.5 ft → 10864.50 ft (0.00 ft)
#    10865.4 ft → 10865.50 ft (0.10 ft)
#    10866.5 ft → 10866.50 ft (0.00 ft)
#
# 🔍 WHY SO FEW MATCHES?
#    • Log data covers: 10842.8 to 11580.5 ft
#    • Lab data covers: 10742.5 to 10866.5 ft
#    • Overlap zone: 10842.8 to 10866.5 ft (23.8 ft)
#    • Tolerance used: 0.5 ft
#    • With 0.5 ft tolerance, only 3 lab samples found matches
#
# 💡 SUGGESTIONS:
#    • Try larger tolerance: 1.0-2.0 ft
#    • Check if depth references match (MD vs TVD)
#    • Verify both datasets use same depth datum

# %%
depth_comparison = pd.DataFrame({
    'Log_Depth': joined_df['Log_Depth'],
    'Lab_Depth': joined_df['Lab_Depth'],
})
depth_comparison.sort_values('Log_Depth', ascending=False)
# Out:
#    Log_Depth  Lab_Depth
# 2    10866.5    10866.5
# 1    10865.5    10865.4
# 0    10864.5    10864.5

# %% [markdown]
# # DATA INTEGRATION ASSESSMENT

# %%
# COMPREHENSIVE DATA INTEGRATION ASSESSMENT
print("🔍 COMPREHENSIVE DATA INTEGRATION ASSESSMENT")
print("=" * 60)

# 1. Basic Statistics
lab_coverage = (len(joined_df) / len(lab_data)) * 100
log_coverage = (len(joined_df) / len(log_df_clean)) * 100

lab_span = lab_data.index.max() - lab_data.index.min()
log_span = log_df_clean.index.max() - log_df_clean.index.min()

matched_span = joined_df['Lab_Depth'].max() - joined_df['Lab_Depth'].min()
avg_depth_diff = abs(joined_df['Log_Depth'] - joined_df['Lab_Depth']).mean()

print(f"📊 DATA OVERVIEW:")
print(f"   • Lab samples: {len(lab_data)} | Log samples: {len(log_df_clean)}")
print(f"   • Matched pairs: {len(joined_df)}")
# print(f"   • Data ratio: 1 lab sample per {len(log_df_clean)//len(lab_data)} log samples") not usful

# 2. Coverage Analysis
print(f"\n📈 COVERAGE ANALYSIS:")
print(f"   • Lab utilization: {lab_coverage:.1f}% ({len(joined_df)}/{len(lab_data)})")
print(f"   • Log coverage: {log_coverage:.1f}% ({len(joined_df)}/{len(log_df_clean)})")

# 3. Depth Range Analysis
print(f"\n📏 DEPTH RANGE ANALYSIS:")
print(f"   • Lab data span: {lab_span:.1f} ft")
print(f"   • Log data span: {log_span:.1f} ft")
print(f"   • Matched (joined) span: {matched_span:.1f} ft")
print(f"   • Lab covers {(lab_span/log_span)*100:.1f}% of well depth")

# 4. Depth Accuracy
print(f"\n🎯 DEPTH ACCURACY:")
print(f"   • Average depth difference: {avg_depth_diff:.2f} ft")
print(f"   • Max depth difference: {abs(joined_df['Log_Depth'] - joined_df['Lab_Depth']).max():.2f} ft")
print(f"   • Min depth difference: {abs(joined_df['Log_Depth'] - joined_df['Lab_Depth']).min():.2f} ft")

# 5. Sampling Density
'''What it means:
📍 SAMPLING DENSITY:

Lab samples: 14.5 per 100 ft = You have about 14-15 lab samples every 100 feet
Log samples: 400.1 per 100 ft = You have about 400 log samples every 100 feet
Why this matters:
Lab Sampling (14.5 per 100 ft):
Spacing: ~7 feet between samples (100 ÷ 14.5 ≈ 7 ft)
Assessment: This is reasonable for lab data - typical for core/cuttings analysis
Cost consideration: Lab analysis is expensive, so sparse sampling is normal
Log Sampling (400.1 per 100 ft):
Spacing: ~0.25 feet between samples (100 ÷ 400 ≈ 0.25 ft = 3 inches)
Assessment: This is excellent - very high resolution
Standard: Typical for modern well logs (6-inch sampling intervals)'''
lab_density = len(lab_data) / (lab_span / 100)
log_density = len(log_df_clean) / (log_span / 100)
print(f"\n📍 SAMPLING DENSITY:")
print(f"   • Lab samples: {lab_density:.1f} per 100 ft")
print(f"   • Log samples: {log_density:.1f} per 100 ft")
# This shows why you have poor matching:
print(f"Lab sample spacing: ~{100/14.5:.1f} feet apart")
print(f"Log sample spacing: ~{100/400.1:.2f} feet apart")
print(f"Density ratio: {400.1/14.5:.1f}:1 (log:lab)")

# 6. Overlap Analysis
overlap_start = max(lab_data.index.min(), log_df_clean.index.min())
overlap_end = min(lab_data.index.max(), log_df_clean.index.max())
overlap_span = overlap_end - overlap_start
print(f"\n🔄 OVERLAP ZONE ANALYSIS:")
print(f"Overlap zone: {overlap_start:.1f} - {overlap_end:.1f} ft")

# Get samples in overlap zone - FIXED the bug
log_overlap = joined_df[(joined_df.index >= overlap_start) & (joined_df.index <= overlap_end)]
lab_overlap = lab_data[(lab_data.index >= overlap_start) & (lab_data.index <= overlap_end)]

print(f"Log samples in overlap: {len(log_overlap)}")
print(f"Lab samples in overlap: {len(lab_overlap)}")

# Show first few samples from each in overlap zone
print(f"\n📍 FIRST 10 SAMPLES IN OVERLAP ZONE:")
overlap_comparison = pd.DataFrame({
    'Log_Depths_Overlap': pd.Series(log_overlap.index[:10]),
    'Lab_Depths_Overlap': pd.Series(lab_overlap.index[:10])
})
print(overlap_comparison)

# Method 3: Show depth spacing analysis
print(f"\n📏 DEPTH SPACING ANALYSIS:")
log_spacing = np.diff(log_df_clean.index)
lab_spacing = np.diff(lab_data.index)

spacing_stats = pd.DataFrame({
    'Log_Spacing': [log_spacing.mean(), log_spacing.std(), log_spacing.min(), log_spacing.max()],
    'Lab_Spacing': [lab_spacing.mean(), lab_spacing.std(), lab_spacing.min(), lab_spacing.max()]
}, index=['Mean', 'Std', 'Min', 'Max'])


# 7. Quality Assessment
print(f"\n⭐ QUALITY ASSESSMENT:")
if lab_coverage >= 80:
    print(f"   ✅ Lab utilization: EXCELLENT ({lab_coverage:.1f}%)")
elif lab_coverage >= 60:
    print(f"   ⚠️ Lab utilization: GOOD ({lab_coverage:.1f}%)")
else:
    print(f"   ❌ Lab utilization: POOR ({lab_coverage:.1f}%)")

if log_coverage >= 50:
    print(f"   ✅ Log coverage: EXCELLENT ({log_coverage:.1f}%)")
elif log_coverage >= 20:
    print(f"   ⚠️ Log coverage: FAIR ({log_coverage:.1f}%)")
else:
    print(f"   ❌ Log coverage: POOR ({log_coverage:.1f}%)")

if matched_span >= 100:
    print(f"   ✅ Depth span: EXCELLENT ({matched_span:.1f} ft)")
elif matched_span >= 50:
    print(f"   ⚠️ Depth span: FAIR ({matched_span:.1f} ft)")
else:
    print(f"   ❌ Depth span: POOR ({matched_span:.1f} ft)")

if avg_depth_diff <= 1:
    print(f"   ✅ Depth accuracy: EXCELLENT ({avg_depth_diff:.2f} ft)")
elif avg_depth_diff <= 2:
    print(f"   ⚠️ Depth accuracy: GOOD ({avg_depth_diff:.2f} ft)")
else:
    print(f"   ❌ Depth accuracy: POOR ({avg_depth_diff:.2f} ft)")

# 8. Overall Assessment
excellent_count = sum([lab_coverage >= 80, log_coverage >= 50, matched_span >= 100, avg_depth_diff <= 1])
good_count = sum([60 <= lab_coverage < 80, 20 <= log_coverage < 50, 50 <= matched_span < 100, 1 < avg_depth_diff <= 2])

print(f"\n🏆 OVERALL ASSESSMENT:")
if excellent_count >= 3:
    print(f"   ✅ EXCELLENT - Ready for comprehensive analysis")
elif excellent_count + good_count >= 3:
    print(f"   ⚠️ GOOD - Suitable for limited analysis")
else:
    print(f"   ❌ POOR - Needs improvement before analysis")

# 9. Recommendations
print(f"\n💡 RECOMMENDATIONS:")
if log_coverage < 10:
    print(f"   • Increase tolerance to {tolerance_ft * 2}-{tolerance_ft * 5} ft")
    print(f"   • Check for systematic depth shifts")
    print(f"   • Verify depth reference datums")
if matched_span < 50:
    print(f"   • Request additional lab samples")
    print(f"   • Focus analysis on overlap zone ({overlap_start:.1f}-{overlap_end:.1f} ft)")
if lab_span/log_span < 0.5:
    print(f"   • Consider interpolation for full-well analysis")
    print(f"   • Use matched data for calibration only")

print(f"\n📝 SUMMARY: Lab utilization is {lab_coverage:.1f}%, but only {log_coverage:.1f}% log coverage limits comprehensive analysis.")
# Out:
# 🔍 COMPREHENSIVE DATA INTEGRATION ASSESSMENT
# ============================================================
# 📊 DATA OVERVIEW:
#    • Lab samples: 18 | Log samples: 2952
#    • Matched pairs: 3
#
# 📈 COVERAGE ANALYSIS:
#    • Lab utilization: 16.7% (3/18)
#    • Log coverage: 0.1% (3/2952)
#
# 📏 DEPTH RANGE ANALYSIS:
#    • Lab data span: 124.0 ft
#    • Log data span: 737.8 ft
#    • Matched (joined) span: 2.0 ft
#    • Lab covers 16.8% of well depth
#
# 🎯 DEPTH ACCURACY:
#    • Average depth difference: 0.03 ft
#    • Max depth difference: 0.10 ft
#    • Min depth difference: 0.00 ft
#
# 📍 SAMPLING DENSITY:
#    • Lab samples: 14.5 per 100 ft
#    • Log samples: 400.1 per 100 ft
# Lab sample spacing: ~6.9 feet apart
# Log sample spacing: ~0.25 feet apart
# Density ratio: 27.6:1 (log:lab)
#
# 🔄 OVERLAP ZONE ANALYSIS:
# Overlap zone: 10842.8 - 10866.5 ft
# Log samples in overlap: 0
# Lab samples in overlap: 3
#
# 📍 FIRST 10 SAMPLES IN OVERLAP ZONE:
#    Log_Depths_Overlap  Lab_Depths_Overlap
# 0                 NaN             10864.5
# 1                 NaN             10865.4
# 2                 NaN             10866.5
#
# 📏 DEPTH SPACING ANALYSIS:
#
# ⭐ QUALITY ASSESSMENT:
#    ❌ Lab utilization: POOR (16.7%)
#    ❌ Log coverage: POOR (0.1%)
#    ❌ Depth span: POOR (2.0 ft)
#    ✅ Depth accuracy: EXCELLENT (0.03 ft)
#
# 🏆 OVERALL ASSESSMENT:
#    ❌ POOR - Needs improvement before analysis
#
# 💡 RECOMMENDATIONS:
#    • Increase tolerance to 1.0-2.5 ft
#    • Check for systematic depth shifts
#    • Verify depth reference datums
#    • Request additional lab samples
#    • Focus analysis on overlap zone (10842.8-10866.5 ft)
#    • Consider interpolation for full-well analysis
#    • Use matched data for calibration only
#
# 📝 SUMMARY: Lab utilization is 16.7%, but only 0.1% log coverage limits comprehensive analysis.

# %% [markdown]
# # Visualizations
